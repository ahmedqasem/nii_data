# %%
import os
import pandas as pd 
import shutil
import matplotlib.pyplot as plt
import SimpleITK as sitk
import glob

# %% [markdown]
# # Get Dataset Information

# %%
# !pwd

# %%
# find all the data thats available
root_folder = '../../datasets/hecktor2022/'
root_image_folder = os.path.join(root_folder, 'imagesTr')
root_labels_folder = os.path.join(root_folder, 'labelsTr')

# %%
print(f'images folder has {len(os.listdir(root_image_folder))} images')
print(f'images folder has {len(os.listdir(root_labels_folder))} labels')

# %%
def extract_institute(file_name):
    # Assuming the institute name is the first 4 characters of the file name
    return file_name[:4]

# %%
def generate_summary(folder_path, img_type):
    # Initialize empty lists to store file names and institutes
    file_names = []
    institutes = []
    image_spacings = []
    image_sizes = []


    # Traverse the folder and its subdirectories
    for i, file_name in enumerate(os.listdir(folder_path)):
        print(i, ' image ', file_name)
        if file_name.endswith(f'__{img_type}.nii.gz'): # or file_name.endswith('__PT.nii.gz'):
            # Extract the institute name from the file name
            institute_name = extract_institute(file_name)

            # Append file name and institute name to the lists
            file_names.append(file_name)
            institutes.append(institute_name)

            # get image information
            selected_image = sitk.ReadImage(os.path.join(root_image_folder, file_name))
            image_spacings.append(str(selected_image.GetSpacing()))
            image_sizes.append(str(selected_image.GetSize()))

    # Create a DataFrame to store the summary
    summary_df = pd.DataFrame({'File Name': file_names, 
                               'Institute': institutes, 
                               'spacing': image_spacings, 
                               'size': image_sizes})
    
    
    # add type as CT 
    summary_df['modality'] = [img_type for x in range(summary_df.shape[0])]
    
    
    return summary_df

# %%
ct_df = generate_summary(root_image_folder, 'CT')
# Out:
# 0  image  MDA-111__CT.nii.gz
# 1  image  CHUM-040__PT.nii.gz
# 2  image  HGJ-048__CT.nii.gz
# 3  image  MDA-126__CT.nii.gz
# 4  image  CHUP-002__PT.nii.gz
# 5  image  MDA-005__CT.nii.gz
# 6  image  CHUV-043__PT.nii.gz
# 7  image  CHUS-048__CT.nii.gz
# 8  image  CHUP-035__PT.nii.gz
# 9  image  MDA-032__CT.nii.gz
# 10  image  CHUM-015__PT.nii.gz
# 11  image  MDA-173__CT.nii.gz
# 12  image  MDA-144__CT.nii.gz
# 13  image  MDA-085__PT.nii.gz
# 14  image  CHUM-022__PT.nii.gz
# 15  image  CHUV-016__PT.nii.gz
# 16  image  MDA-067__CT.nii.gz
# 17  image  CHUP-060__PT.nii.gz
# 18  image  MDA-191__PT.nii.gz
# 19  image  MDA-050__CT.nii.gz
# 20  image  CHUP-057__PT.nii.gz
# 21  image  CHUV-021__PT.nii.gz
# 22  image  CHUM-008__CT.nii.gz
# 23  image  MDA-098__CT.nii.gz
# 24  image  HGJ-037__PT.nii.gz
# 25  image  MDA-159__PT.nii.gz
# 26  image  HGJ-062__PT.nii.gz
# 27  image  HGJ-055__PT.nii.gz
# 28  image  HMR-028__CT.nii.gz
# 29  image  CHUS-080__CT.nii.gz
# 30  image  MDA-018__PT.nii.gz
# 31  image  HGJ-080__CT.nii.gz
# 32  image  CHUP-028__CT.nii.gz
# 33  image  CHUS-055__PT.nii.gz
# 34  image  HGJ-081__PT.nii.gz
# 35  image  CHUP-029__PT.nii.gz
# 36  image  MDA-019__CT.nii.gz
# 37  image  HMR-029__PT.nii.gz
# 38  image  CHUS-081__PT.nii.gz
# 39  image  CHUS-036__CT.nii.gz
# 40  image  MDA-158__CT.nii.gz
# 41  image  MDA-099__PT.nii.gz
# 42  image  HGJ-036__CT.nii.gz
# 43  image  MDA-051__PT.nii.gz
# 44  image  CHUP-056__CT.nii.gz
# 45  image  CHUV-020__CT.nii.gz
# 46  image  MDA-190__CT.nii.gz
# 47  image  CHUV-017__CT.nii.gz
# 48  image  MDA-066__PT.nii.gz
# 49  image  CHUP-061__CT.nii.gz
# 50  image  MDA-084__CT.nii.gz
# 51  image  CHUM-023__CT.nii.gz
# 52  image  MDA-145__PT.nii.gz
# 53  image  MDA-172__PT.nii.gz
# 54  image  CHUM-014__CT.nii.gz
# 55  image  CHUV-042__CT.nii.gz
# 56  image  CHUS-049__PT.nii.gz
# 57  image  CHUP-034__CT.nii.gz
# 58  image  MDA-033__PT.nii.gz
# 59  image  CHUP-003__CT.nii.gz
# 60  image  MDA-004__PT.nii.gz
# 61  image  MDA-127__PT.nii.gz
# 62  image  CHUM-041__CT.nii.gz
# 63  image  HMR-034__CT.nii.gz
# 64  image  MDA-110__PT.nii.gz
# 65  image  HMR-012__CT.nii.gz
# 66  image  MDA-101__PT.nii.gz
# 67  image  MDA-136__PT.nii.gz
# 68  image  HGJ-058__PT.nii.gz
# 69  image  HMR-025__CT.nii.gz
# 70  image  CHUM-050__CT.nii.gz
# 71  image  MDA-015__PT.nii.gz
# 72  image  CHUP-012__CT.nii.gz
# 73  image  MDA-022__PT.nii.gz
# 74  image  CHUP-025__CT.nii.gz
# 75  image  CHUV-053__CT.nii.gz
# 76  image  CHUS-058__PT.nii.gz
# 77  image  MDA-163__PT.nii.gz
# 78  image  CHUM-032__CT.nii.gz
# 79  image  MDA-095__CT.nii.gz
# 80  image  MDA-154__PT.nii.gz
# 81  image  CHUP-070__CT.nii.gz
# 82  image  MDA-077__PT.nii.gz
# 83  image  CHUV-006__CT.nii.gz
# 84  image  CHUV-031__CT.nii.gz
# 85  image  CHUP-047__CT.nii.gz
# 86  image  MDA-040__PT.nii.gz
# 87  image  MDA-181__CT.nii.gz
# 88  image  CHUM-018__PT.nii.gz
# 89  image  HGJ-010__CT.nii.gz
# 90  image  MDA-149__CT.nii.gz
# 91  image  MDA-088__PT.nii.gz
# 92  image  CHUS-010__CT.nii.gz
# 93  image  CHUS-027__CT.nii.gz
# 94  image  HGJ-072__CT.nii.gz
# 95  image  CHUS-090__PT.nii.gz
# 96  image  CHUS-045__CT.nii.gz
# 97  image  HGJ-090__PT.nii.gz
# 98  image  CHUP-038__PT.nii.gz
# 99  image  HGJ-091__CT.nii.gz
# 100  image  CHUP-039__CT.nii.gz
# 101  image  CHUS-073__PT.nii.gz
# 102  image  CHUS-091__CT.nii.gz
# 103  image  HGJ-073__PT.nii.gz
# 104  image  CHUS-026__PT.nii.gz
# 105  image  MDA-089__CT.nii.gz
# 106  image  HGJ-026__PT.nii.gz
# 107  image  MDA-148__PT.nii.gz
# 108  image  CHUM-019__CT.nii.gz
# 109  image  MDA-180__PT.nii.gz
# 110  image  CHUV-030__PT.nii.gz
# 111  image  CHUP-046__PT.nii.gz
# 112  image  MDA-041__CT.nii.gz
# 113  image  CHUP-071__PT.nii.gz
# 114  image  MDA-076__CT.nii.gz
# 115  image  CHUV-007__PT.nii.gz
# 116  image  MDA-155__CT.nii.gz
# 117  image  CHUM-033__PT.nii.gz
# 118  image  MDA-094__PT.nii.gz
# 119  image  MDA-162__CT.nii.gz
# 120  image  MDA-023__CT.nii.gz
# 121  image  CHUP-024__PT.nii.gz
# 122  image  CHUV-052__PT.nii.gz
# 123  image  MDA-014__CT.nii.gz
# 124  image  CHUP-013__PT.nii.gz
# 125  image  HMR-024__PT.nii.gz
# 126  image  CHUM-051__PT.nii.gz
# 127  image  MDA-137__CT.nii.gz
# 128  image  MDA-100__CT.nii.gz
# 129  image  HMR-013__PT.nii.gz
# 130  image  MDA-199__PT.nii.gz
# 131  image  CHUV-029__PT.nii.gz
# 132  image  CHUS-022__CT.nii.gz
# 133  image  MDA-058__CT.nii.gz
# 134  image  CHUP-068__PT.nii.gz
# 135  image  CHUS-015__CT.nii.gz
# 136  image  HGJ-015__CT.nii.gz
# 137  image  CHUS-101__CT.nii.gz
# 138  image  CHUS-040__CT.nii.gz
# 139  image  CHUS-077__CT.nii.gz
# 140  image  CHUS-095__PT.nii.gz
# 141  image  CHUM-048__PT.nii.gz
# 142  image  MDA-119__CT.nii.gz
# 143  image  HGJ-077__CT.nii.gz
# 144  image  HGJ-088__CT.nii.gz
# 145  image  MDA-027__PT.nii.gz
# 146  image  CHUP-020__CT.nii.gz
# 147  image  MDA-010__PT.nii.gz
# 148  image  CHUP-017__CT.nii.gz
# 149  image  MDA-133__PT.nii.gz
# 150  image  CHUS-088__CT.nii.gz
# 151  image  CHUM-055__CT.nii.gz
# 152  image  HMR-020__CT.nii.gz
# 153  image  CHUM-062__CT.nii.gz
# 154  image  MDA-104__PT.nii.gz
# 155  image  CHUP-042__CT.nii.gz
# 156  image  MDA-045__PT.nii.gz
# 157  image  CHUV-034__CT.nii.gz
# 158  image  MDA-184__CT.nii.gz
# 159  image  CHUV-003__CT.nii.gz
# 160  image  CHUS-008__PT.nii.gz
# 161  image  CHUP-075__CT.nii.gz
# 162  image  MDA-072__PT.nii.gz
# 163  image  MDA-090__CT.nii.gz
# 164  image  CHUM-037__CT.nii.gz
# 165  image  MDA-151__PT.nii.gz
# 166  image  MDA-166__PT.nii.gz
# 167  image  HGJ-008__PT.nii.gz
# 168  image  CHUM-001__PT.nii.gz
# 169  image  MDA-167__CT.nii.gz
# 170  image  MDA-150__CT.nii.gz
# 171  image  MDA-091__PT.nii.gz
# 172  image  CHUM-036__PT.nii.gz
# 173  image  CHUV-002__PT.nii.gz
# 174  image  CHUS-009__CT.nii.gz
# 175  image  CHUP-074__PT.nii.gz
# 176  image  MDA-073__CT.nii.gz
# 177  image  MDA-185__PT.nii.gz
# 178  image  CHUP-043__PT.nii.gz
# 179  image  MDA-044__CT.nii.gz
# 180  image  CHUV-035__PT.nii.gz
# 181  image  MDA-105__CT.nii.gz
# 182  image  HMR-016__PT.nii.gz
# 183  image  CHUM-063__PT.nii.gz
# 184  image  CHUS-089__PT.nii.gz
# 185  image  CHUM-054__PT.nii.gz
# 186  image  HMR-021__PT.nii.gz
# 187  image  MDA-132__CT.nii.gz
# 188  image  MDA-011__CT.nii.gz
# 189  image  CHUP-016__PT.nii.gz
# 190  image  HGJ-089__PT.nii.gz
# 191  image  MDA-026__CT.nii.gz
# 192  image  HGJ-076__PT.nii.gz
# 193  image  MDA-118__PT.nii.gz
# 194  image  CHUS-094__CT.nii.gz
# 195  image  CHUM-049__CT.nii.gz
# 196  image  CHUS-076__PT.nii.gz
# 197  image  CHUS-041__PT.nii.gz
# 198  image  CHUS-100__PT.nii.gz
# 199  image  CHUP-069__CT.nii.gz
# 200  image  CHUV-028__CT.nii.gz
# 201  image  MDA-059__PT.nii.gz
# 202  image  MDA-198__CT.nii.gz
# 203  image  MDA-048__PT.nii.gz
# 204  image  CHUV-039__CT.nii.gz
# 205  image  MDA-189__CT.nii.gz
# 206  image  CHUS-005__PT.nii.gz
# 207  image  HGJ-032__PT.nii.gz
# 208  image  CHUS-050__PT.nii.gz
# 209  image  HGJ-085__CT.nii.gz
# 210  image  CHUS-067__PT.nii.gz
# 211  image  CHUS-085__CT.nii.gz
# 212  image  CHUM-058__CT.nii.gz
# 213  image  HGJ-050__PT.nii.gz
# 214  image  HGJ-067__PT.nii.gz
# 215  image  MDA-109__PT.nii.gz
# 216  image  CHUP-030__PT.nii.gz
# 217  image  MDA-037__CT.nii.gz
# 218  image  CHUV-046__PT.nii.gz
# 219  image  CHUP-007__PT.nii.gz
# 220  image  HMR-030__PT.nii.gz
# 221  image  CHUS-098__PT.nii.gz
# 222  image  CHUM-045__PT.nii.gz
# 223  image  MDA-123__CT.nii.gz
# 224  image  MDA-114__CT.nii.gz
# 225  image  MDA-194__PT.nii.gz
# 226  image  CHUV-024__PT.nii.gz
# 227  image  MDA-055__CT.nii.gz
# 228  image  CHUP-052__PT.nii.gz
# 229  image  MDA-062__CT.nii.gz
# 230  image  CHUP-065__PT.nii.gz
# 231  image  CHUV-013__PT.nii.gz
# 232  image  MDA-141__CT.nii.gz
# 233  image  CHUM-027__PT.nii.gz
# 234  image  MDA-080__PT.nii.gz
# 235  image  HGJ-018__CT.nii.gz
# 236  image  CHUM-010__PT.nii.gz
# 237  image  MDA-176__CT.nii.gz
# 238  image  MDA-177__PT.nii.gz
# 239  image  CHUM-011__CT.nii.gz
# 240  image  CHUM-026__CT.nii.gz
# 241  image  MDA-081__CT.nii.gz
# 242  image  MDA-140__PT.nii.gz
# 243  image  MDA-063__PT.nii.gz
# 244  image  CHUP-064__CT.nii.gz
# 245  image  CHUV-012__CT.nii.gz
# 246  image  CHUS-019__PT.nii.gz
# 247  image  CHUV-025__CT.nii.gz
# 248  image  MDA-054__PT.nii.gz
# 249  image  CHUP-053__CT.nii.gz
# 250  image  MDA-195__CT.nii.gz
# 251  image  MDA-115__PT.nii.gz
# 252  image  MDA-122__PT.nii.gz
# 253  image  CHUM-044__CT.nii.gz
# 254  image  CHUP-006__CT.nii.gz
# 255  image  MDA-001__PT.nii.gz
# 256  image  MDA-036__PT.nii.gz
# 257  image  CHUV-047__CT.nii.gz
# 258  image  MDA-108__CT.nii.gz
# 259  image  HGJ-066__CT.nii.gz
# 260  image  CHUM-059__PT.nii.gz
# 261  image  CHUS-066__CT.nii.gz
# 262  image  CHUS-051__CT.nii.gz
# 263  image  CHUS-004__CT.nii.gz
# 264  image  MDA-188__PT.nii.gz
# 265  image  MDA-049__CT.nii.gz
# 266  image  CHUV-038__PT.nii.gz
# 267  image  CHUS-033__CT.nii.gz
# 268  image  CHUS-061__CT.nii.gz
# 269  image  CHUS-056__CT.nii.gz
# 270  image  HGJ-083__PT.nii.gz
# 271  image  MDA-138__CT.nii.gz
# 272  image  CHUS-083__PT.nii.gz
# 273  image  CHUV-008__PT.nii.gz
# 274  image  CHUS-003__CT.nii.gz
# 275  image  MDA-079__CT.nii.gz
# 276  image  CHUP-049__PT.nii.gz
# 277  image  HGJ-034__CT.nii.gz
# 278  image  MDA-064__PT.nii.gz
# 279  image  CHUP-063__CT.nii.gz
# 280  image  CHUV-015__CT.nii.gz
# 281  image  MDA-192__CT.nii.gz
# 282  image  CHUV-022__CT.nii.gz
# 283  image  MDA-053__PT.nii.gz
# 284  image  CHUP-054__CT.nii.gz
# 285  image  CHUM-016__CT.nii.gz
# 286  image  MDA-170__PT.nii.gz
# 287  image  MDA-147__PT.nii.gz
# 288  image  CHUM-021__CT.nii.gz
# 289  image  MDA-086__CT.nii.gz
# 290  image  HGJ-029__PT.nii.gz
# 291  image  CHUP-001__CT.nii.gz
# 292  image  MDA-006__PT.nii.gz
# 293  image  CHUP-036__CT.nii.gz
# 294  image  MDA-031__PT.nii.gz
# 295  image  CHUV-040__CT.nii.gz
# 296  image  MDA-112__PT.nii.gz
# 297  image  HMR-001__CT.nii.gz
# 298  image  CHUM-043__CT.nii.gz
# 299  image  MDA-125__PT.nii.gz
# 300  image  MDA-124__CT.nii.gz
# 301  image  CHUM-042__PT.nii.gz
# 302  image  MDA-113__CT.nii.gz
# 303  image  CHUP-037__PT.nii.gz
# 304  image  MDA-030__CT.nii.gz
# 305  image  CHUV-041__PT.nii.gz
# 306  image  CHUP-000__PT.nii.gz
# 307  image  MDA-007__CT.nii.gz
# 308  image  MDA-087__PT.nii.gz
# 309  image  HGJ-028__CT.nii.gz
# 310  image  MDA-146__CT.nii.gz
# 311  image  MDA-171__CT.nii.gz
# 312  image  CHUM-017__PT.nii.gz
# 313  image  CHUV-023__PT.nii.gz
# 314  image  CHUS-028__CT.nii.gz
# 315  image  MDA-052__CT.nii.gz
# 316  image  CHUP-055__PT.nii.gz
# 317  image  MDA-193__PT.nii.gz
# 318  image  MDA-065__CT.nii.gz
# 319  image  CHUP-062__PT.nii.gz
# 320  image  CHUV-014__PT.nii.gz
# 321  image  HGJ-035__PT.nii.gz
# 322  image  CHUP-048__CT.nii.gz
# 323  image  CHUS-035__PT.nii.gz
# 324  image  CHUV-009__CT.nii.gz
# 325  image  MDA-078__PT.nii.gz
# 326  image  HGJ-057__PT.nii.gz
# 327  image  MDA-139__PT.nii.gz
# 328  image  CHUS-057__PT.nii.gz
# 329  image  HGJ-082__CT.nii.gz
# 330  image  CHUS-060__PT.nii.gz
# 331  image  CHUS-046__PT.nii.gz
# 332  image  HGJ-071__PT.nii.gz
# 333  image  HGJ-046__PT.nii.gz
# 334  image  MDA-128__PT.nii.gz
# 335  image  MDA-069__PT.nii.gz
# 336  image  CHUV-018__CT.nii.gz
# 337  image  CHUS-013__PT.nii.gz
# 338  image  CHUP-059__CT.nii.gz
# 339  image  HGJ-013__PT.nii.gz
# 340  image  CHUV-005__PT.nii.gz
# 341  image  CHUP-073__PT.nii.gz
# 342  image  MDA-074__CT.nii.gz
# 343  image  CHUP-044__PT.nii.gz
# 344  image  MDA-043__CT.nii.gz
# 345  image  CHUV-032__PT.nii.gz
# 346  image  CHUS-039__CT.nii.gz
# 347  image  MDA-182__PT.nii.gz
# 348  image  MDA-160__CT.nii.gz
# 349  image  CHUM-006__PT.nii.gz
# 350  image  MDA-096__PT.nii.gz
# 351  image  HGJ-039__CT.nii.gz
# 352  image  MDA-157__CT.nii.gz
# 353  image  MDA-016__CT.nii.gz
# 354  image  CHUP-011__PT.nii.gz
# 355  image  CHUV-050__PT.nii.gz
# 356  image  MDA-021__CT.nii.gz
# 357  image  CHUP-026__PT.nii.gz
# 358  image  HMR-011__PT.nii.gz
# 359  image  CHUM-064__PT.nii.gz
# 360  image  MDA-102__CT.nii.gz
# 361  image  MDA-135__CT.nii.gz
# 362  image  CHUM-053__PT.nii.gz
# 363  image  MDA-134__PT.nii.gz
# 364  image  MDA-103__PT.nii.gz
# 365  image  CHUM-065__CT.nii.gz
# 366  image  CHUV-051__CT.nii.gz
# 367  image  MDA-020__PT.nii.gz
# 368  image  CHUP-027__CT.nii.gz
# 369  image  MDA-017__PT.nii.gz
# 370  image  CHUP-010__CT.nii.gz
# 371  image  MDA-156__PT.nii.gz
# 372  image  MDA-097__CT.nii.gz
# 373  image  HGJ-038__PT.nii.gz
# 374  image  CHUM-030__CT.nii.gz
# 375  image  CHUM-007__CT.nii.gz
# 376  image  MDA-161__PT.nii.gz
# 377  image  MDA-183__CT.nii.gz
# 378  image  MDA-042__PT.nii.gz
# 379  image  CHUV-033__CT.nii.gz
# 380  image  CHUS-038__PT.nii.gz
# 381  image  CHUV-004__CT.nii.gz
# 382  image  CHUP-072__CT.nii.gz
# 383  image  MDA-075__PT.nii.gz
# 384  image  HGJ-025__CT.nii.gz
# 385  image  CHUP-058__PT.nii.gz
# 386  image  MDA-068__CT.nii.gz
# 387  image  CHUV-019__PT.nii.gz
# 388  image  MDA-129__CT.nii.gz
# 389  image  HGJ-070__CT.nii.gz
# 390  image  HGJ-092__PT.nii.gz
# 391  image  CHUS-047__CT.nii.gz
# 392  image  CHUM-034__PT.nii.gz
# 393  image  MDA-093__PT.nii.gz
# 394  image  MDA-152__CT.nii.gz
# 395  image  MDA-165__CT.nii.gz
# 396  image  CHUV-037__PT.nii.gz
# 397  image  CHUP-041__PT.nii.gz
# 398  image  MDA-046__CT.nii.gz
# 399  image  MDA-187__PT.nii.gz
# 400  image  MDA-071__CT.nii.gz
# 401  image  MDA-130__CT.nii.gz
# 402  image  HMR-023__PT.nii.gz
# 403  image  CHUM-056__PT.nii.gz
# 404  image  CHUM-061__PT.nii.gz
# 405  image  HMR-014__PT.nii.gz
# 406  image  HGJ-069__CT.nii.gz
# 407  image  MDA-107__CT.nii.gz
# 408  image  MDA-024__CT.nii.gz
# 409  image  CHUP-023__PT.nii.gz
# 410  image  CHUS-069__CT.nii.gz
# 411  image  MDA-013__CT.nii.gz
# 412  image  CHUS-096__CT.nii.gz
# 413  image  HGJ-043__PT.nii.gz
# 414  image  HGJ-074__PT.nii.gz
# 415  image  CHUV-048__CT.nii.gz
# 416  image  CHUS-043__PT.nii.gz
# 417  image  MDA-039__PT.nii.gz
# 418  image  CHUP-009__CT.nii.gz
# 419  image  CHUS-074__PT.nii.gz
# 420  image  CHUM-029__CT.nii.gz
# 421  image  HGJ-016__PT.nii.gz
# 422  image  MDA-178__PT.nii.gz
# 423  image  CHUS-021__PT.nii.gz
# 424  image  CHUS-016__PT.nii.gz
# 425  image  CHUS-020__CT.nii.gz
# 426  image  MDA-179__CT.nii.gz
# 427  image  HGJ-017__CT.nii.gz
# 428  image  CHUP-008__PT.nii.gz
# 429  image  CHUV-049__PT.nii.gz
# 430  image  CHUS-042__CT.nii.gz
# 431  image  MDA-038__CT.nii.gz
# 432  image  CHUS-097__PT.nii.gz
# 433  image  CHUS-068__PT.nii.gz
# 434  image  MDA-012__PT.nii.gz
# 435  image  CHUP-015__CT.nii.gz
# 436  image  MDA-025__PT.nii.gz
# 437  image  CHUP-022__CT.nii.gz
# 438  image  MDA-106__PT.nii.gz
# 439  image  CHUM-060__CT.nii.gz
# 440  image  CHUM-057__CT.nii.gz
# 441  image  MDA-131__PT.nii.gz
# 442  image  MDA-070__PT.nii.gz
# 443  image  CHUV-001__CT.nii.gz
# 444  image  MDA-186__CT.nii.gz
# 445  image  CHUV-036__CT.nii.gz
# 446  image  CHUP-040__CT.nii.gz
# 447  image  MDA-047__PT.nii.gz
# 448  image  CHUM-002__CT.nii.gz
# 449  image  MDA-164__PT.nii.gz
# 450  image  MDA-153__PT.nii.gz
# 451  image  CHUM-035__CT.nii.gz
# 452  image  MDA-092__CT.nii.gz
# 453  image  HMR-040__CT.nii.gz
# 454  image  MDA-142__PT.nii.gz
# 455  image  MDA-083__CT.nii.gz
# 456  image  CHUM-024__CT.nii.gz
# 457  image  CHUM-013__CT.nii.gz
# 458  image  MDA-175__PT.nii.gz
# 459  image  MDA-197__CT.nii.gz
# 460  image  MDA-056__PT.nii.gz
# 461  image  CHUP-051__CT.nii.gz
# 462  image  CHUV-027__CT.nii.gz
# 463  image  CHUV-010__CT.nii.gz
# 464  image  MDA-061__PT.nii.gz
# 465  image  CHUP-066__CT.nii.gz
# 466  image  CHUM-046__CT.nii.gz
# 467  image  MDA-120__PT.nii.gz
# 468  image  MDA-117__PT.nii.gz
# 469  image  HMR-004__CT.nii.gz
# 470  image  CHUV-045__CT.nii.gz
# 471  image  CHUP-033__CT.nii.gz
# 472  image  MDA-034__PT.nii.gz
# 473  image  CHUP-004__CT.nii.gz
# 474  image  MDA-003__PT.nii.gz
# 475  image  HGJ-053__CT.nii.gz
# 476  image  CHUS-086__PT.nii.gz
# 477  image  HGJ-086__PT.nii.gz
# 478  image  MDA-029__CT.nii.gz
# 479  image  CHUS-053__CT.nii.gz
# 480  image  CHUS-064__CT.nii.gz
# 481  image  CHUP-019__PT.nii.gz
# 482  image  CHUM-039__PT.nii.gz
# 483  image  HGJ-031__CT.nii.gz
# 484  image  MDA-168__CT.nii.gz
# 485  image  CHUS-031__CT.nii.gz
# 486  image  MDA-201__CT.nii.gz
# 487  image  CHUS-006__CT.nii.gz
# 488  image  CHUS-007__PT.nii.gz
# 489  image  MDA-200__PT.nii.gz
# 490  image  CHUS-030__PT.nii.gz
# 491  image  HGJ-007__PT.nii.gz
# 492  image  MDA-169__PT.nii.gz
# 493  image  CHUM-038__CT.nii.gz
# 494  image  HGJ-030__PT.nii.gz
# 495  image  CHUS-065__PT.nii.gz
# 496  image  CHUP-018__CT.nii.gz
# 497  image  HGJ-087__CT.nii.gz
# 498  image  MDA-028__PT.nii.gz
# 499  image  CHUS-052__PT.nii.gz
# 500  image  HGJ-065__PT.nii.gz
# 501  image  HGJ-052__PT.nii.gz
# 502  image  CHUS-087__CT.nii.gz
# 503  image  CHUP-005__PT.nii.gz
# 504  image  CHUS-078__CT.nii.gz
# 505  image  CHUV-044__PT.nii.gz
# 506  image  CHUP-032__PT.nii.gz
# 507  image  MDA-035__CT.nii.gz
# 508  image  HMR-005__PT.nii.gz
# 509  image  HGJ-078__CT.nii.gz
# 510  image  MDA-116__CT.nii.gz
# 511  image  MDA-121__CT.nii.gz
# 512  image  CHUM-047__PT.nii.gz
# 513  image  CHUV-011__PT.nii.gz
# 514  image  MDA-060__CT.nii.gz
# 515  image  CHUP-067__PT.nii.gz
# 516  image  MDA-057__CT.nii.gz
# 517  image  CHUP-050__PT.nii.gz
# 518  image  CHUV-026__PT.nii.gz
# 519  image  MDA-196__PT.nii.gz
# 520  image  MDA-174__CT.nii.gz
# 521  image  CHUM-012__PT.nii.gz
# 522  image  MDA-082__PT.nii.gz
# 523  image  MDA-143__CT.nii.gz
# 524  image  MDA-026__PT.nii.gz
# 525  image  HGJ-089__CT.nii.gz
# 526  image  MDA-011__PT.nii.gz
# 527  image  CHUP-016__CT.nii.gz
# 528  image  HMR-021__CT.nii.gz
# 529  image  CHUM-054__CT.nii.gz
# 530  image  CHUS-089__CT.nii.gz
# 531  image  MDA-132__PT.nii.gz
# 532  image  MDA-105__PT.nii.gz
# 533  image  CHUM-063__CT.nii.gz
# 534  image  HMR-016__CT.nii.gz
# 535  image  MDA-185__CT.nii.gz
# 536  image  CHUV-035__CT.nii.gz
# 537  image  CHUP-043__CT.nii.gz
# 538  image  MDA-044__PT.nii.gz
# 539  image  CHUP-074__CT.nii.gz
# 540  image  MDA-073__PT.nii.gz
# 541  image  CHUS-009__PT.nii.gz
# 542  image  CHUV-002__CT.nii.gz
# 543  image  MDA-150__PT.nii.gz
# 544  image  CHUM-036__CT.nii.gz
# 545  image  MDA-091__CT.nii.gz
# 546  image  CHUM-001__CT.nii.gz
# 547  image  MDA-167__PT.nii.gz
# 548  image  MDA-059__CT.nii.gz
# 549  image  CHUV-028__PT.nii.gz
# 550  image  MDA-198__PT.nii.gz
# 551  image  CHUP-069__PT.nii.gz
# 552  image  CHUS-100__CT.nii.gz
# 553  image  CHUS-041__CT.nii.gz
# 554  image  CHUS-076__CT.nii.gz
# 555  image  CHUM-049__PT.nii.gz
# 556  image  CHUS-094__PT.nii.gz
# 557  image  HGJ-076__CT.nii.gz
# 558  image  MDA-118__CT.nii.gz
# 559  image  MDA-119__PT.nii.gz
# 560  image  HGJ-077__PT.nii.gz
# 561  image  CHUM-048__CT.nii.gz
# 562  image  CHUS-095__CT.nii.gz
# 563  image  CHUS-077__PT.nii.gz
# 564  image  CHUS-040__PT.nii.gz
# 565  image  HGJ-015__PT.nii.gz
# 566  image  CHUS-101__PT.nii.gz
# 567  image  CHUS-015__PT.nii.gz
# 568  image  CHUP-068__CT.nii.gz
# 569  image  MDA-199__CT.nii.gz
# 570  image  MDA-058__PT.nii.gz
# 571  image  CHUS-022__PT.nii.gz
# 572  image  CHUV-029__CT.nii.gz
# 573  image  MDA-166__CT.nii.gz
# 574  image  HGJ-008__CT.nii.gz
# 575  image  CHUM-037__PT.nii.gz
# 576  image  MDA-090__PT.nii.gz
# 577  image  MDA-151__CT.nii.gz
# 578  image  CHUP-075__PT.nii.gz
# 579  image  MDA-072__CT.nii.gz
# 580  image  CHUS-008__CT.nii.gz
# 581  image  CHUV-003__PT.nii.gz
# 582  image  CHUV-034__PT.nii.gz
# 583  image  CHUP-042__PT.nii.gz
# 584  image  MDA-045__CT.nii.gz
# 585  image  MDA-184__PT.nii.gz
# 586  image  CHUM-062__PT.nii.gz
# 587  image  MDA-104__CT.nii.gz
# 588  image  MDA-133__CT.nii.gz
# 589  image  HMR-020__PT.nii.gz
# 590  image  CHUM-055__PT.nii.gz
# 591  image  CHUS-088__PT.nii.gz
# 592  image  MDA-010__CT.nii.gz
# 593  image  CHUP-017__PT.nii.gz
# 594  image  MDA-027__CT.nii.gz
# 595  image  CHUP-020__PT.nii.gz
# 596  image  HGJ-088__PT.nii.gz
# 597  image  CHUV-047__PT.nii.gz
# 598  image  MDA-036__CT.nii.gz
# 599  image  CHUP-006__PT.nii.gz
# 600  image  MDA-001__CT.nii.gz
# 601  image  MDA-122__CT.nii.gz
# 602  image  CHUM-044__PT.nii.gz
# 603  image  MDA-115__CT.nii.gz
# 604  image  MDA-054__CT.nii.gz
# 605  image  CHUP-053__PT.nii.gz
# 606  image  CHUV-025__PT.nii.gz
# 607  image  MDA-195__PT.nii.gz
# 608  image  CHUS-019__CT.nii.gz
# 609  image  CHUV-012__PT.nii.gz
# 610  image  MDA-063__CT.nii.gz
# 611  image  CHUP-064__PT.nii.gz
# 612  image  MDA-081__PT.nii.gz
# 613  image  CHUM-026__PT.nii.gz
# 614  image  MDA-140__CT.nii.gz
# 615  image  MDA-177__CT.nii.gz
# 616  image  CHUM-011__PT.nii.gz
# 617  image  MDA-188__CT.nii.gz
# 618  image  CHUS-033__PT.nii.gz
# 619  image  CHUV-038__CT.nii.gz
# 620  image  MDA-049__PT.nii.gz
# 621  image  CHUS-004__PT.nii.gz
# 622  image  CHUS-051__PT.nii.gz
# 623  image  CHUS-066__PT.nii.gz
# 624  image  CHUM-059__CT.nii.gz
# 625  image  MDA-108__PT.nii.gz
# 626  image  HGJ-066__PT.nii.gz
# 627  image  HGJ-067__CT.nii.gz
# 628  image  MDA-109__CT.nii.gz
# 629  image  HGJ-050__CT.nii.gz
# 630  image  CHUM-058__PT.nii.gz
# 631  image  CHUS-085__PT.nii.gz
# 632  image  CHUS-067__CT.nii.gz
# 633  image  HGJ-085__PT.nii.gz
# 634  image  CHUS-050__CT.nii.gz
# 635  image  HGJ-032__CT.nii.gz
# 636  image  CHUS-005__CT.nii.gz
# 637  image  CHUV-039__PT.nii.gz
# 638  image  MDA-048__CT.nii.gz
# 639  image  MDA-189__PT.nii.gz
# 640  image  CHUM-010__CT.nii.gz
# 641  image  HGJ-018__PT.nii.gz
# 642  image  MDA-176__PT.nii.gz
# 643  image  MDA-141__PT.nii.gz
# 644  image  MDA-080__CT.nii.gz
# 645  image  CHUM-027__CT.nii.gz
# 646  image  CHUV-013__CT.nii.gz
# 647  image  MDA-062__PT.nii.gz
# 648  image  CHUP-065__CT.nii.gz
# 649  image  MDA-194__CT.nii.gz
# 650  image  MDA-055__PT.nii.gz
# 651  image  CHUP-052__CT.nii.gz
# 652  image  CHUV-024__CT.nii.gz
# 653  image  MDA-114__PT.nii.gz
# 654  image  CHUM-045__CT.nii.gz
# 655  image  CHUS-098__CT.nii.gz
# 656  image  HMR-030__CT.nii.gz
# 657  image  MDA-123__PT.nii.gz
# 658  image  CHUP-007__CT.nii.gz
# 659  image  CHUV-046__CT.nii.gz
# 660  image  CHUP-030__CT.nii.gz
# 661  image  MDA-037__PT.nii.gz
# 662  image  MDA-158__PT.nii.gz
# 663  image  HGJ-036__PT.nii.gz
# 664  image  MDA-099__CT.nii.gz
# 665  image  CHUS-036__PT.nii.gz
# 666  image  CHUS-081__CT.nii.gz
# 667  image  HMR-029__CT.nii.gz
# 668  image  MDA-019__PT.nii.gz
# 669  image  CHUP-029__CT.nii.gz
# 670  image  HGJ-081__CT.nii.gz
# 671  image  MDA-110__CT.nii.gz
# 672  image  MDA-127__CT.nii.gz
# 673  image  HMR-034__PT.nii.gz
# 674  image  CHUM-041__PT.nii.gz
# 675  image  CHUP-003__PT.nii.gz
# 676  image  MDA-004__CT.nii.gz
# 677  image  CHUP-034__PT.nii.gz
# 678  image  MDA-033__CT.nii.gz
# 679  image  CHUS-049__CT.nii.gz
# 680  image  CHUV-042__PT.nii.gz
# 681  image  MDA-172__CT.nii.gz
# 682  image  CHUM-014__PT.nii.gz
# 683  image  CHUM-023__PT.nii.gz
# 684  image  MDA-084__PT.nii.gz
# 685  image  MDA-145__CT.nii.gz
# 686  image  MDA-066__CT.nii.gz
# 687  image  CHUP-061__PT.nii.gz
# 688  image  CHUV-017__PT.nii.gz
# 689  image  CHUV-020__PT.nii.gz
# 690  image  MDA-051__CT.nii.gz
# 691  image  CHUP-056__PT.nii.gz
# 692  image  MDA-190__PT.nii.gz
# 693  image  MDA-191__CT.nii.gz
# 694  image  CHUV-021__CT.nii.gz
# 695  image  MDA-050__PT.nii.gz
# 696  image  CHUP-057__CT.nii.gz
# 697  image  MDA-067__PT.nii.gz
# 698  image  CHUP-060__CT.nii.gz
# 699  image  CHUV-016__CT.nii.gz
# 700  image  MDA-144__PT.nii.gz
# 701  image  CHUM-022__CT.nii.gz
# 702  image  MDA-085__CT.nii.gz
# 703  image  CHUM-015__CT.nii.gz
# 704  image  MDA-173__PT.nii.gz
# 705  image  CHUP-035__CT.nii.gz
# 706  image  MDA-032__PT.nii.gz
# 707  image  CHUS-048__PT.nii.gz
# 708  image  CHUV-043__CT.nii.gz
# 709  image  CHUP-002__CT.nii.gz
# 710  image  MDA-005__PT.nii.gz
# 711  image  HGJ-048__PT.nii.gz
# 712  image  CHUM-040__CT.nii.gz
# 713  image  MDA-126__PT.nii.gz
# 714  image  MDA-111__PT.nii.gz
# 715  image  CHUS-055__CT.nii.gz
# 716  image  CHUP-028__PT.nii.gz
# 717  image  HGJ-080__PT.nii.gz
# 718  image  MDA-018__CT.nii.gz
# 719  image  CHUS-080__PT.nii.gz
# 720  image  HGJ-055__CT.nii.gz
# 721  image  HMR-028__PT.nii.gz
# 722  image  HGJ-062__CT.nii.gz
# 723  image  HGJ-037__CT.nii.gz
# 724  image  MDA-098__PT.nii.gz
# 725  image  MDA-159__CT.nii.gz
# 726  image  CHUM-008__PT.nii.gz
# 727  image  CHUM-019__PT.nii.gz
# 728  image  HGJ-026__CT.nii.gz
# 729  image  MDA-089__PT.nii.gz
# 730  image  MDA-148__CT.nii.gz
# 731  image  CHUS-026__CT.nii.gz
# 732  image  HGJ-073__CT.nii.gz
# 733  image  CHUS-091__PT.nii.gz
# 734  image  CHUS-073__CT.nii.gz
# 735  image  CHUP-039__PT.nii.gz
# 736  image  HGJ-091__PT.nii.gz
# 737  image  MDA-100__PT.nii.gz
# 738  image  HMR-013__CT.nii.gz
# 739  image  CHUM-051__CT.nii.gz
# 740  image  HMR-024__CT.nii.gz
# 741  image  MDA-137__PT.nii.gz
# 742  image  MDA-014__PT.nii.gz
# 743  image  CHUP-013__CT.nii.gz
# 744  image  CHUV-052__CT.nii.gz
# 745  image  MDA-023__PT.nii.gz
# 746  image  CHUP-024__CT.nii.gz
# 747  image  MDA-162__PT.nii.gz
# 748  image  MDA-155__PT.nii.gz
# 749  image  MDA-094__CT.nii.gz
# 750  image  CHUM-033__CT.nii.gz
# 751  image  CHUV-007__CT.nii.gz
# 752  image  CHUP-071__CT.nii.gz
# 753  image  MDA-076__PT.nii.gz
# 754  image  MDA-180__CT.nii.gz
# 755  image  CHUP-046__CT.nii.gz
# 756  image  MDA-041__PT.nii.gz
# 757  image  CHUV-030__CT.nii.gz
# 758  image  CHUP-047__PT.nii.gz
# 759  image  MDA-040__CT.nii.gz
# 760  image  CHUV-031__PT.nii.gz
# 761  image  MDA-181__PT.nii.gz
# 762  image  CHUV-006__PT.nii.gz
# 763  image  CHUP-070__PT.nii.gz
# 764  image  MDA-077__CT.nii.gz
# 765  image  MDA-095__PT.nii.gz
# 766  image  CHUM-032__PT.nii.gz
# 767  image  MDA-154__CT.nii.gz
# 768  image  MDA-163__CT.nii.gz
# 769  image  CHUS-058__CT.nii.gz
# 770  image  CHUV-053__PT.nii.gz
# 771  image  MDA-022__CT.nii.gz
# 772  image  CHUP-025__PT.nii.gz
# 773  image  MDA-015__CT.nii.gz
# 774  image  CHUP-012__PT.nii.gz
# 775  image  MDA-136__CT.nii.gz
# 776  image  CHUM-050__PT.nii.gz
# 777  image  HGJ-058__CT.nii.gz
# 778  image  HMR-025__PT.nii.gz
# 779  image  HMR-012__PT.nii.gz
# 780  image  MDA-101__CT.nii.gz
# 781  image  CHUP-038__CT.nii.gz
# 782  image  HGJ-090__CT.nii.gz
# 783  image  CHUS-045__PT.nii.gz
# 784  image  CHUS-090__CT.nii.gz
# 785  image  HGJ-072__PT.nii.gz
# 786  image  CHUS-027__PT.nii.gz
# 787  image  CHUS-010__PT.nii.gz
# 788  image  MDA-149__PT.nii.gz
# 789  image  MDA-088__CT.nii.gz
# 790  image  HGJ-010__PT.nii.gz
# 791  image  CHUM-018__CT.nii.gz
# 792  image  CHUS-097__CT.nii.gz
# 793  image  MDA-038__PT.nii.gz
# 794  image  CHUS-042__PT.nii.gz
# 795  image  CHUV-049__CT.nii.gz
# 796  image  CHUP-008__CT.nii.gz
# 797  image  MDA-179__PT.nii.gz
# 798  image  HGJ-017__PT.nii.gz
# 799  image  CHUS-020__PT.nii.gz
# 800  image  MDA-153__CT.nii.gz
# 801  image  HMR-040__PT.nii.gz
# 802  image  MDA-092__PT.nii.gz
# 803  image  CHUM-035__PT.nii.gz
# 804  image  CHUM-002__PT.nii.gz
# 805  image  MDA-164__CT.nii.gz
# 806  image  MDA-186__PT.nii.gz
# 807  image  CHUP-040__PT.nii.gz
# 808  image  MDA-047__CT.nii.gz
# 809  image  CHUV-036__PT.nii.gz
# 810  image  CHUV-001__PT.nii.gz
# 811  image  MDA-070__CT.nii.gz
# 812  image  CHUM-057__PT.nii.gz
# 813  image  MDA-131__CT.nii.gz
# 814  image  MDA-106__CT.nii.gz
# 815  image  CHUM-060__PT.nii.gz
# 816  image  MDA-025__CT.nii.gz
# 817  image  CHUP-022__PT.nii.gz
# 818  image  MDA-012__CT.nii.gz
# 819  image  CHUP-015__PT.nii.gz
# 820  image  CHUS-068__CT.nii.gz
# 821  image  MDA-013__PT.nii.gz
# 822  image  CHUS-069__PT.nii.gz
# 823  image  MDA-024__PT.nii.gz
# 824  image  CHUP-023__CT.nii.gz
# 825  image  HMR-014__CT.nii.gz
# 826  image  HGJ-069__PT.nii.gz
# 827  image  CHUM-061__CT.nii.gz
# 828  image  MDA-107__PT.nii.gz
# 829  image  MDA-130__PT.nii.gz
# 830  image  CHUM-056__CT.nii.gz
# 831  image  HMR-023__CT.nii.gz
# 832  image  MDA-071__PT.nii.gz
# 833  image  CHUP-041__CT.nii.gz
# 834  image  MDA-046__PT.nii.gz
# 835  image  CHUV-037__CT.nii.gz
# 836  image  MDA-187__CT.nii.gz
# 837  image  MDA-165__PT.nii.gz
# 838  image  MDA-093__CT.nii.gz
# 839  image  CHUM-034__CT.nii.gz
# 840  image  MDA-152__PT.nii.gz
# 841  image  CHUS-016__CT.nii.gz
# 842  image  CHUS-021__CT.nii.gz
# 843  image  HGJ-016__CT.nii.gz
# 844  image  MDA-178__CT.nii.gz
# 845  image  CHUM-029__PT.nii.gz
# 846  image  CHUS-074__CT.nii.gz
# 847  image  CHUP-009__PT.nii.gz
# 848  image  MDA-039__CT.nii.gz
# 849  image  CHUS-043__CT.nii.gz
# 850  image  CHUV-048__PT.nii.gz
# 851  image  HGJ-074__CT.nii.gz
# 852  image  HGJ-043__CT.nii.gz
# 853  image  CHUS-096__PT.nii.gz
# 854  image  CHUS-087__PT.nii.gz
# 855  image  HGJ-052__CT.nii.gz
# 856  image  HGJ-065__CT.nii.gz
# 857  image  CHUS-052__CT.nii.gz
# 858  image  MDA-028__CT.nii.gz
# 859  image  HGJ-087__PT.nii.gz
# 860  image  CHUP-018__PT.nii.gz
# 861  image  CHUS-065__CT.nii.gz
# 862  image  HGJ-030__CT.nii.gz
# 863  image  CHUM-038__PT.nii.gz
# 864  image  HGJ-007__CT.nii.gz
# 865  image  MDA-169__CT.nii.gz
# 866  image  CHUS-030__CT.nii.gz
# 867  image  CHUS-007__CT.nii.gz
# 868  image  MDA-200__CT.nii.gz
# 869  image  MDA-082__CT.nii.gz
# 870  image  MDA-143__PT.nii.gz
# 871  image  MDA-174__PT.nii.gz
# 872  image  CHUM-012__CT.nii.gz
# 873  image  CHUV-026__CT.nii.gz
# 874  image  MDA-057__PT.nii.gz
# 875  image  CHUP-050__CT.nii.gz
# 876  image  MDA-196__CT.nii.gz
# 877  image  MDA-060__PT.nii.gz
# 878  image  CHUP-067__CT.nii.gz
# 879  image  CHUV-011__CT.nii.gz
# 880  image  MDA-121__PT.nii.gz
# 881  image  CHUM-047__CT.nii.gz
# 882  image  HMR-005__CT.nii.gz
# 883  image  HGJ-078__PT.nii.gz
# 884  image  MDA-116__PT.nii.gz
# 885  image  CHUP-032__CT.nii.gz
# 886  image  MDA-035__PT.nii.gz
# 887  image  CHUV-044__CT.nii.gz
# 888  image  CHUS-078__PT.nii.gz
# 889  image  CHUP-005__CT.nii.gz
# 890  image  CHUP-004__PT.nii.gz
# 891  image  MDA-003__CT.nii.gz
# 892  image  CHUP-033__PT.nii.gz
# 893  image  MDA-034__CT.nii.gz
# 894  image  CHUV-045__PT.nii.gz
# 895  image  MDA-117__CT.nii.gz
# 896  image  HMR-004__PT.nii.gz
# 897  image  CHUM-046__PT.nii.gz
# 898  image  MDA-120__CT.nii.gz
# 899  image  MDA-061__CT.nii.gz
# 900  image  CHUP-066__PT.nii.gz
# 901  image  CHUV-010__PT.nii.gz
# 902  image  MDA-197__PT.nii.gz
# 903  image  CHUV-027__PT.nii.gz
# 904  image  MDA-056__CT.nii.gz
# 905  image  CHUP-051__PT.nii.gz
# 906  image  CHUM-013__PT.nii.gz
# 907  image  MDA-175__CT.nii.gz
# 908  image  MDA-142__CT.nii.gz
# 909  image  CHUM-024__PT.nii.gz
# 910  image  MDA-083__PT.nii.gz
# 911  image  MDA-201__PT.nii.gz
# 912  image  CHUS-006__PT.nii.gz
# 913  image  CHUS-031__PT.nii.gz
# 914  image  MDA-168__PT.nii.gz
# 915  image  HGJ-031__PT.nii.gz
# 916  image  CHUM-039__CT.nii.gz
# 917  image  CHUP-019__CT.nii.gz
# 918  image  CHUS-064__PT.nii.gz
# 919  image  CHUS-053__PT.nii.gz
# 920  image  MDA-029__PT.nii.gz
# 921  image  HGJ-086__CT.nii.gz
# 922  image  CHUS-086__CT.nii.gz
# 923  image  HGJ-053__PT.nii.gz
# 924  image  CHUV-014__CT.nii.gz
# 925  image  MDA-065__PT.nii.gz
# 926  image  CHUP-062__CT.nii.gz
# 927  image  MDA-052__PT.nii.gz
# 928  image  CHUP-055__CT.nii.gz
# 929  image  CHUS-028__PT.nii.gz
# 930  image  CHUV-023__CT.nii.gz
# 931  image  MDA-193__CT.nii.gz
# 932  image  MDA-171__PT.nii.gz
# 933  image  CHUM-017__CT.nii.gz
# 934  image  HGJ-028__PT.nii.gz
# 935  image  MDA-087__CT.nii.gz
# 936  image  MDA-146__PT.nii.gz
# 937  image  CHUP-000__CT.nii.gz
# 938  image  MDA-007__PT.nii.gz
# 939  image  CHUV-041__CT.nii.gz
# 940  image  CHUP-037__CT.nii.gz
# 941  image  MDA-030__PT.nii.gz
# 942  image  MDA-113__PT.nii.gz
# 943  image  MDA-124__PT.nii.gz
# 944  image  CHUM-042__CT.nii.gz
# 945  image  CHUS-060__CT.nii.gz
# 946  image  HGJ-082__PT.nii.gz
# 947  image  CHUS-057__CT.nii.gz
# 948  image  HGJ-057__CT.nii.gz
# 949  image  MDA-139__CT.nii.gz
# 950  image  MDA-078__CT.nii.gz
# 951  image  CHUV-009__PT.nii.gz
# 952  image  CHUS-035__CT.nii.gz
# 953  image  CHUP-048__PT.nii.gz
# 954  image  HGJ-035__CT.nii.gz
# 955  image  HGJ-034__PT.nii.gz
# 956  image  CHUP-049__CT.nii.gz
# 957  image  MDA-079__PT.nii.gz
# 958  image  CHUS-003__PT.nii.gz
# 959  image  CHUV-008__CT.nii.gz
# 960  image  MDA-138__PT.nii.gz
# 961  image  CHUS-083__CT.nii.gz
# 962  image  HGJ-083__CT.nii.gz
# 963  image  CHUS-056__PT.nii.gz
# 964  image  CHUS-061__PT.nii.gz
# 965  image  CHUM-043__PT.nii.gz
# 966  image  MDA-125__CT.nii.gz
# 967  image  MDA-112__CT.nii.gz
# 968  image  HMR-001__PT.nii.gz
# 969  image  CHUV-040__PT.nii.gz
# 970  image  CHUP-036__PT.nii.gz
# 971  image  MDA-031__CT.nii.gz
# 972  image  CHUP-001__PT.nii.gz
# 973  image  MDA-006__CT.nii.gz
# 974  image  MDA-147__CT.nii.gz
# 975  image  HGJ-029__CT.nii.gz
# 976  image  MDA-086__PT.nii.gz
# 977  image  CHUM-021__PT.nii.gz
# 978  image  CHUM-016__PT.nii.gz
# 979  image  MDA-170__CT.nii.gz
# 980  image  MDA-192__PT.nii.gz
# 981  image  MDA-053__CT.nii.gz
# 982  image  CHUP-054__PT.nii.gz
# 983  image  CHUV-022__PT.nii.gz
# 984  image  CHUV-015__PT.nii.gz
# 985  image  MDA-064__CT.nii.gz
# 986  image  CHUP-063__PT.nii.gz
# 987  image  CHUP-072__PT.nii.gz
# 988  image  MDA-075__CT.nii.gz
# 989  image  CHUV-004__PT.nii.gz
# 990  image  MDA-183__PT.nii.gz
# 991  image  CHUS-038__CT.nii.gz
# 992  image  CHUV-033__PT.nii.gz
# 993  image  MDA-042__CT.nii.gz
# 994  image  CHUM-007__PT.nii.gz
# 995  image  MDA-161__CT.nii.gz
# 996  image  MDA-156__CT.nii.gz
# 997  image  CHUM-030__PT.nii.gz
# 998  image  HGJ-038__CT.nii.gz
# 999  image  MDA-097__PT.nii.gz
# 1000  image  MDA-017__CT.nii.gz
# 1001  image  CHUP-010__PT.nii.gz
# 1002  image  MDA-020__CT.nii.gz
# 1003  image  CHUP-027__PT.nii.gz
# 1004  image  CHUV-051__PT.nii.gz
# 1005  image  MDA-103__CT.nii.gz
# 1006  image  CHUM-065__PT.nii.gz
# 1007  image  MDA-134__CT.nii.gz
# 1008  image  CHUS-047__PT.nii.gz
# 1009  image  HGJ-092__CT.nii.gz
# 1010  image  HGJ-070__PT.nii.gz
# 1011  image  MDA-129__PT.nii.gz
# 1012  image  CHUV-019__CT.nii.gz
# 1013  image  MDA-068__PT.nii.gz
# 1014  image  CHUP-058__CT.nii.gz
# 1015  image  HGJ-025__PT.nii.gz
# 1016  image  HGJ-013__CT.nii.gz
# 1017  image  CHUP-059__PT.nii.gz
# 1018  image  CHUS-013__CT.nii.gz
# 1019  image  CHUV-018__PT.nii.gz
# 1020  image  MDA-069__CT.nii.gz
# 1021  image  HGJ-046__CT.nii.gz
# 1022  image  MDA-128__CT.nii.gz
# 1023  image  HGJ-071__CT.nii.gz
# 1024  image  CHUS-046__CT.nii.gz
# 1025  image  MDA-135__PT.nii.gz
# 1026  image  CHUM-053__CT.nii.gz
# 1027  image  CHUM-064__CT.nii.gz
# 1028  image  HMR-011__CT.nii.gz
# 1029  image  MDA-102__PT.nii.gz
# 1030  image  MDA-021__PT.nii.gz
# 1031  image  CHUP-026__CT.nii.gz
# 1032  image  CHUV-050__CT.nii.gz
# 1033  image  MDA-016__PT.nii.gz
# 1034  image  CHUP-011__CT.nii.gz
# 1035  image  HGJ-039__PT.nii.gz
# 1036  image  MDA-096__CT.nii.gz
# 1037  image  MDA-157__PT.nii.gz
# 1038  image  MDA-160__PT.nii.gz
# 1039  image  CHUM-006__CT.nii.gz
# 1040  image  CHUS-039__PT.nii.gz
# 1041  image  CHUV-032__CT.nii.gz
# 1042  image  CHUP-044__CT.nii.gz
# 1043  image  MDA-043__PT.nii.gz
# 1044  image  MDA-182__CT.nii.gz
# 1045  image  CHUP-073__CT.nii.gz
# 1046  image  MDA-074__PT.nii.gz
# 1047  image  CHUV-005__CT.nii.gz

# %%
ct_df
# Out:
#                File Name Institute  \
# 0     MDA-111__CT.nii.gz      MDA-
# 1     HGJ-048__CT.nii.gz      HGJ-
# 2     MDA-126__CT.nii.gz      MDA-
# 3     MDA-005__CT.nii.gz      MDA-
# 4    CHUS-048__CT.nii.gz      CHUS
# ..                   ...       ...
# 519  CHUV-032__CT.nii.gz      CHUV
# 520  CHUP-044__CT.nii.gz      CHUP
# 521   MDA-182__CT.nii.gz      MDA-
# 522  CHUP-073__CT.nii.gz      CHUP
# 523  CHUV-005__CT.nii.gz      CHUV
#
#                                                spacing             size  \
# 0                          (0.9765625, 0.9765625, 5.0)  (512, 512, 195)
# 1    (0.9765620231628418, 0.9765620231628418, 3.269...   (512, 512, 91)
# 2    (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 127)
# 3    (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 267)
# 4                            (1.171875, 1.171875, 3.0)  (512, 512, 134)
# ..                                                 ...              ...
# 519  (1.3671879768371582, 1.3671879768371582, 3.269...  (512, 512, 335)
# 520                        (0.9765625, 0.9765625, 1.5)  (512, 512, 652)
# 521  (0.9765620231628418, 0.9765620231628418, 3.269...   (512, 512, 91)
# 522                        (0.9765625, 0.9765625, 1.5)  (512, 512, 568)
# 523  (1.3671879768371582, 1.3671879768371582, 3.269...  (512, 512, 335)
#
#     modality
# 0         CT
# 1         CT
# 2         CT
# 3         CT
# 4         CT
# ..       ...
# 519       CT
# 520       CT
# 521       CT
# 522       CT
# 523       CT
#
# [524 rows x 5 columns]

# %%
ct_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 524 entries, 0 to 523
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   File Name  524 non-null    object
#  1   Institute  524 non-null    object
#  2   spacing    524 non-null    object
#  3   size       524 non-null    object
#  4   modality   524 non-null    object
# dtypes: object(5)
# memory usage: 20.6+ KB

# %%
pt_df = generate_summary(root_image_folder, 'PT')
pt_df.head()
# Out:
# 0  image  MDA-111__CT.nii.gz
# 1  image  CHUM-040__PT.nii.gz
# 2  image  HGJ-048__CT.nii.gz
# 3  image  MDA-126__CT.nii.gz
# 4  image  CHUP-002__PT.nii.gz
# 5  image  MDA-005__CT.nii.gz
# 6  image  CHUV-043__PT.nii.gz
# 7  image  CHUS-048__CT.nii.gz
# 8  image  CHUP-035__PT.nii.gz
# 9  image  MDA-032__CT.nii.gz
# 10  image  CHUM-015__PT.nii.gz
# 11  image  MDA-173__CT.nii.gz
# 12  image  MDA-144__CT.nii.gz
# 13  image  MDA-085__PT.nii.gz
# 14  image  CHUM-022__PT.nii.gz
# 15  image  CHUV-016__PT.nii.gz
# 16  image  MDA-067__CT.nii.gz
# 17  image  CHUP-060__PT.nii.gz
# 18  image  MDA-191__PT.nii.gz
# 19  image  MDA-050__CT.nii.gz
# 20  image  CHUP-057__PT.nii.gz
# 21  image  CHUV-021__PT.nii.gz
# 22  image  CHUM-008__CT.nii.gz
# 23  image  MDA-098__CT.nii.gz
# 24  image  HGJ-037__PT.nii.gz
# 25  image  MDA-159__PT.nii.gz
# 26  image  HGJ-062__PT.nii.gz
# 27  image  HGJ-055__PT.nii.gz
# 28  image  HMR-028__CT.nii.gz
# 29  image  CHUS-080__CT.nii.gz
# 30  image  MDA-018__PT.nii.gz
# 31  image  HGJ-080__CT.nii.gz
# 32  image  CHUP-028__CT.nii.gz
# 33  image  CHUS-055__PT.nii.gz
# 34  image  HGJ-081__PT.nii.gz
# 35  image  CHUP-029__PT.nii.gz
# 36  image  MDA-019__CT.nii.gz
# 37  image  HMR-029__PT.nii.gz
# 38  image  CHUS-081__PT.nii.gz
# 39  image  CHUS-036__CT.nii.gz
# 40  image  MDA-158__CT.nii.gz
# 41  image  MDA-099__PT.nii.gz
# 42  image  HGJ-036__CT.nii.gz
# 43  image  MDA-051__PT.nii.gz
# 44  image  CHUP-056__CT.nii.gz
# 45  image  CHUV-020__CT.nii.gz
# 46  image  MDA-190__CT.nii.gz
# 47  image  CHUV-017__CT.nii.gz
# 48  image  MDA-066__PT.nii.gz
# 49  image  CHUP-061__CT.nii.gz
# 50  image  MDA-084__CT.nii.gz
# 51  image  CHUM-023__CT.nii.gz
# 52  image  MDA-145__PT.nii.gz
# 53  image  MDA-172__PT.nii.gz
# 54  image  CHUM-014__CT.nii.gz
# 55  image  CHUV-042__CT.nii.gz
# 56  image  CHUS-049__PT.nii.gz
# 57  image  CHUP-034__CT.nii.gz
# 58  image  MDA-033__PT.nii.gz
# 59  image  CHUP-003__CT.nii.gz
# 60  image  MDA-004__PT.nii.gz
# 61  image  MDA-127__PT.nii.gz
# 62  image  CHUM-041__CT.nii.gz
# 63  image  HMR-034__CT.nii.gz
# 64  image  MDA-110__PT.nii.gz
# 65  image  HMR-012__CT.nii.gz
# 66  image  MDA-101__PT.nii.gz
# 67  image  MDA-136__PT.nii.gz
# 68  image  HGJ-058__PT.nii.gz
# 69  image  HMR-025__CT.nii.gz
# 70  image  CHUM-050__CT.nii.gz
# 71  image  MDA-015__PT.nii.gz
# 72  image  CHUP-012__CT.nii.gz
# 73  image  MDA-022__PT.nii.gz
# 74  image  CHUP-025__CT.nii.gz
# 75  image  CHUV-053__CT.nii.gz
# 76  image  CHUS-058__PT.nii.gz
# 77  image  MDA-163__PT.nii.gz
# 78  image  CHUM-032__CT.nii.gz
# 79  image  MDA-095__CT.nii.gz
# 80  image  MDA-154__PT.nii.gz
# 81  image  CHUP-070__CT.nii.gz
# 82  image  MDA-077__PT.nii.gz
# 83  image  CHUV-006__CT.nii.gz
# 84  image  CHUV-031__CT.nii.gz
# 85  image  CHUP-047__CT.nii.gz
# 86  image  MDA-040__PT.nii.gz
# 87  image  MDA-181__CT.nii.gz
# 88  image  CHUM-018__PT.nii.gz
# 89  image  HGJ-010__CT.nii.gz
# 90  image  MDA-149__CT.nii.gz
# 91  image  MDA-088__PT.nii.gz
# 92  image  CHUS-010__CT.nii.gz
# 93  image  CHUS-027__CT.nii.gz
# 94  image  HGJ-072__CT.nii.gz
# 95  image  CHUS-090__PT.nii.gz
# 96  image  CHUS-045__CT.nii.gz
# 97  image  HGJ-090__PT.nii.gz
# 98  image  CHUP-038__PT.nii.gz
# 99  image  HGJ-091__CT.nii.gz
# 100  image  CHUP-039__CT.nii.gz
# 101  image  CHUS-073__PT.nii.gz
# 102  image  CHUS-091__CT.nii.gz
# 103  image  HGJ-073__PT.nii.gz
# 104  image  CHUS-026__PT.nii.gz
# 105  image  MDA-089__CT.nii.gz
# 106  image  HGJ-026__PT.nii.gz
# 107  image  MDA-148__PT.nii.gz
# 108  image  CHUM-019__CT.nii.gz
# 109  image  MDA-180__PT.nii.gz
# 110  image  CHUV-030__PT.nii.gz
# 111  image  CHUP-046__PT.nii.gz
# 112  image  MDA-041__CT.nii.gz
# 113  image  CHUP-071__PT.nii.gz
# 114  image  MDA-076__CT.nii.gz
# 115  image  CHUV-007__PT.nii.gz
# 116  image  MDA-155__CT.nii.gz
# 117  image  CHUM-033__PT.nii.gz
# 118  image  MDA-094__PT.nii.gz
# 119  image  MDA-162__CT.nii.gz
# 120  image  MDA-023__CT.nii.gz
# 121  image  CHUP-024__PT.nii.gz
# 122  image  CHUV-052__PT.nii.gz
# 123  image  MDA-014__CT.nii.gz
# 124  image  CHUP-013__PT.nii.gz
# 125  image  HMR-024__PT.nii.gz
# 126  image  CHUM-051__PT.nii.gz
# 127  image  MDA-137__CT.nii.gz
# 128  image  MDA-100__CT.nii.gz
# 129  image  HMR-013__PT.nii.gz
# 130  image  MDA-199__PT.nii.gz
# 131  image  CHUV-029__PT.nii.gz
# 132  image  CHUS-022__CT.nii.gz
# 133  image  MDA-058__CT.nii.gz
# 134  image  CHUP-068__PT.nii.gz
# 135  image  CHUS-015__CT.nii.gz
# 136  image  HGJ-015__CT.nii.gz
# 137  image  CHUS-101__CT.nii.gz
# 138  image  CHUS-040__CT.nii.gz
# 139  image  CHUS-077__CT.nii.gz
# 140  image  CHUS-095__PT.nii.gz
# 141  image  CHUM-048__PT.nii.gz
# 142  image  MDA-119__CT.nii.gz
# 143  image  HGJ-077__CT.nii.gz
# 144  image  HGJ-088__CT.nii.gz
# 145  image  MDA-027__PT.nii.gz
# 146  image  CHUP-020__CT.nii.gz
# 147  image  MDA-010__PT.nii.gz
# 148  image  CHUP-017__CT.nii.gz
# 149  image  MDA-133__PT.nii.gz
# 150  image  CHUS-088__CT.nii.gz
# 151  image  CHUM-055__CT.nii.gz
# 152  image  HMR-020__CT.nii.gz
# 153  image  CHUM-062__CT.nii.gz
# 154  image  MDA-104__PT.nii.gz
# 155  image  CHUP-042__CT.nii.gz
# 156  image  MDA-045__PT.nii.gz
# 157  image  CHUV-034__CT.nii.gz
# 158  image  MDA-184__CT.nii.gz
# 159  image  CHUV-003__CT.nii.gz
# 160  image  CHUS-008__PT.nii.gz
# 161  image  CHUP-075__CT.nii.gz
# 162  image  MDA-072__PT.nii.gz
# 163  image  MDA-090__CT.nii.gz
# 164  image  CHUM-037__CT.nii.gz
# 165  image  MDA-151__PT.nii.gz
# 166  image  MDA-166__PT.nii.gz
# 167  image  HGJ-008__PT.nii.gz
# 168  image  CHUM-001__PT.nii.gz
# 169  image  MDA-167__CT.nii.gz
# 170  image  MDA-150__CT.nii.gz
# 171  image  MDA-091__PT.nii.gz
# 172  image  CHUM-036__PT.nii.gz
# 173  image  CHUV-002__PT.nii.gz
# 174  image  CHUS-009__CT.nii.gz
# 175  image  CHUP-074__PT.nii.gz
# 176  image  MDA-073__CT.nii.gz
# 177  image  MDA-185__PT.nii.gz
# 178  image  CHUP-043__PT.nii.gz
# 179  image  MDA-044__CT.nii.gz
# 180  image  CHUV-035__PT.nii.gz
# 181  image  MDA-105__CT.nii.gz
# 182  image  HMR-016__PT.nii.gz
# 183  image  CHUM-063__PT.nii.gz
# 184  image  CHUS-089__PT.nii.gz
# 185  image  CHUM-054__PT.nii.gz
# 186  image  HMR-021__PT.nii.gz
# 187  image  MDA-132__CT.nii.gz
# 188  image  MDA-011__CT.nii.gz
# 189  image  CHUP-016__PT.nii.gz
# 190  image  HGJ-089__PT.nii.gz
# 191  image  MDA-026__CT.nii.gz
# 192  image  HGJ-076__PT.nii.gz
# 193  image  MDA-118__PT.nii.gz
# 194  image  CHUS-094__CT.nii.gz
# 195  image  CHUM-049__CT.nii.gz
# 196  image  CHUS-076__PT.nii.gz
# 197  image  CHUS-041__PT.nii.gz
# 198  image  CHUS-100__PT.nii.gz
# 199  image  CHUP-069__CT.nii.gz
# 200  image  CHUV-028__CT.nii.gz
# 201  image  MDA-059__PT.nii.gz
# 202  image  MDA-198__CT.nii.gz
# 203  image  MDA-048__PT.nii.gz
# 204  image  CHUV-039__CT.nii.gz
# 205  image  MDA-189__CT.nii.gz
# 206  image  CHUS-005__PT.nii.gz
# 207  image  HGJ-032__PT.nii.gz
# 208  image  CHUS-050__PT.nii.gz
# 209  image  HGJ-085__CT.nii.gz
# 210  image  CHUS-067__PT.nii.gz
# 211  image  CHUS-085__CT.nii.gz
# 212  image  CHUM-058__CT.nii.gz
# 213  image  HGJ-050__PT.nii.gz
# 214  image  HGJ-067__PT.nii.gz
# 215  image  MDA-109__PT.nii.gz
# 216  image  CHUP-030__PT.nii.gz
# 217  image  MDA-037__CT.nii.gz
# 218  image  CHUV-046__PT.nii.gz
# 219  image  CHUP-007__PT.nii.gz
# 220  image  HMR-030__PT.nii.gz
# 221  image  CHUS-098__PT.nii.gz
# 222  image  CHUM-045__PT.nii.gz
# 223  image  MDA-123__CT.nii.gz
# 224  image  MDA-114__CT.nii.gz
# 225  image  MDA-194__PT.nii.gz
# 226  image  CHUV-024__PT.nii.gz
# 227  image  MDA-055__CT.nii.gz
# 228  image  CHUP-052__PT.nii.gz
# 229  image  MDA-062__CT.nii.gz
# 230  image  CHUP-065__PT.nii.gz
# 231  image  CHUV-013__PT.nii.gz
# 232  image  MDA-141__CT.nii.gz
# 233  image  CHUM-027__PT.nii.gz
# 234  image  MDA-080__PT.nii.gz
# 235  image  HGJ-018__CT.nii.gz
# 236  image  CHUM-010__PT.nii.gz
# 237  image  MDA-176__CT.nii.gz
# 238  image  MDA-177__PT.nii.gz
# 239  image  CHUM-011__CT.nii.gz
# 240  image  CHUM-026__CT.nii.gz
# 241  image  MDA-081__CT.nii.gz
# 242  image  MDA-140__PT.nii.gz
# 243  image  MDA-063__PT.nii.gz
# 244  image  CHUP-064__CT.nii.gz
# 245  image  CHUV-012__CT.nii.gz
# 246  image  CHUS-019__PT.nii.gz
# 247  image  CHUV-025__CT.nii.gz
# 248  image  MDA-054__PT.nii.gz
# 249  image  CHUP-053__CT.nii.gz
# 250  image  MDA-195__CT.nii.gz
# 251  image  MDA-115__PT.nii.gz
# 252  image  MDA-122__PT.nii.gz
# 253  image  CHUM-044__CT.nii.gz
# 254  image  CHUP-006__CT.nii.gz
# 255  image  MDA-001__PT.nii.gz
# 256  image  MDA-036__PT.nii.gz
# 257  image  CHUV-047__CT.nii.gz
# 258  image  MDA-108__CT.nii.gz
# 259  image  HGJ-066__CT.nii.gz
# 260  image  CHUM-059__PT.nii.gz
# 261  image  CHUS-066__CT.nii.gz
# 262  image  CHUS-051__CT.nii.gz
# 263  image  CHUS-004__CT.nii.gz
# 264  image  MDA-188__PT.nii.gz
# 265  image  MDA-049__CT.nii.gz
# 266  image  CHUV-038__PT.nii.gz
# 267  image  CHUS-033__CT.nii.gz
# 268  image  CHUS-061__CT.nii.gz
# 269  image  CHUS-056__CT.nii.gz
# 270  image  HGJ-083__PT.nii.gz
# 271  image  MDA-138__CT.nii.gz
# 272  image  CHUS-083__PT.nii.gz
# 273  image  CHUV-008__PT.nii.gz
# 274  image  CHUS-003__CT.nii.gz
# 275  image  MDA-079__CT.nii.gz
# 276  image  CHUP-049__PT.nii.gz
# 277  image  HGJ-034__CT.nii.gz
# 278  image  MDA-064__PT.nii.gz
# 279  image  CHUP-063__CT.nii.gz
# 280  image  CHUV-015__CT.nii.gz
# 281  image  MDA-192__CT.nii.gz
# 282  image  CHUV-022__CT.nii.gz
# 283  image  MDA-053__PT.nii.gz
# 284  image  CHUP-054__CT.nii.gz
# 285  image  CHUM-016__CT.nii.gz
# 286  image  MDA-170__PT.nii.gz
# 287  image  MDA-147__PT.nii.gz
# 288  image  CHUM-021__CT.nii.gz
# 289  image  MDA-086__CT.nii.gz
# 290  image  HGJ-029__PT.nii.gz
# 291  image  CHUP-001__CT.nii.gz
# 292  image  MDA-006__PT.nii.gz
# 293  image  CHUP-036__CT.nii.gz
# 294  image  MDA-031__PT.nii.gz
# 295  image  CHUV-040__CT.nii.gz
# 296  image  MDA-112__PT.nii.gz
# 297  image  HMR-001__CT.nii.gz
# 298  image  CHUM-043__CT.nii.gz
# 299  image  MDA-125__PT.nii.gz
# 300  image  MDA-124__CT.nii.gz
# 301  image  CHUM-042__PT.nii.gz
# 302  image  MDA-113__CT.nii.gz
# 303  image  CHUP-037__PT.nii.gz
# 304  image  MDA-030__CT.nii.gz
# 305  image  CHUV-041__PT.nii.gz
# 306  image  CHUP-000__PT.nii.gz
# 307  image  MDA-007__CT.nii.gz
# 308  image  MDA-087__PT.nii.gz
# 309  image  HGJ-028__CT.nii.gz
# 310  image  MDA-146__CT.nii.gz
# 311  image  MDA-171__CT.nii.gz
# 312  image  CHUM-017__PT.nii.gz
# 313  image  CHUV-023__PT.nii.gz
# 314  image  CHUS-028__CT.nii.gz
# 315  image  MDA-052__CT.nii.gz
# 316  image  CHUP-055__PT.nii.gz
# 317  image  MDA-193__PT.nii.gz
# 318  image  MDA-065__CT.nii.gz
# 319  image  CHUP-062__PT.nii.gz
# 320  image  CHUV-014__PT.nii.gz
# 321  image  HGJ-035__PT.nii.gz
# 322  image  CHUP-048__CT.nii.gz
# 323  image  CHUS-035__PT.nii.gz
# 324  image  CHUV-009__CT.nii.gz
# 325  image  MDA-078__PT.nii.gz
# 326  image  HGJ-057__PT.nii.gz
# 327  image  MDA-139__PT.nii.gz
# 328  image  CHUS-057__PT.nii.gz
# 329  image  HGJ-082__CT.nii.gz
# 330  image  CHUS-060__PT.nii.gz
# 331  image  CHUS-046__PT.nii.gz
# 332  image  HGJ-071__PT.nii.gz
# 333  image  HGJ-046__PT.nii.gz
# 334  image  MDA-128__PT.nii.gz
# 335  image  MDA-069__PT.nii.gz
# 336  image  CHUV-018__CT.nii.gz
# 337  image  CHUS-013__PT.nii.gz
# 338  image  CHUP-059__CT.nii.gz
# 339  image  HGJ-013__PT.nii.gz
# 340  image  CHUV-005__PT.nii.gz
# 341  image  CHUP-073__PT.nii.gz
# 342  image  MDA-074__CT.nii.gz
# 343  image  CHUP-044__PT.nii.gz
# 344  image  MDA-043__CT.nii.gz
# 345  image  CHUV-032__PT.nii.gz
# 346  image  CHUS-039__CT.nii.gz
# 347  image  MDA-182__PT.nii.gz
# 348  image  MDA-160__CT.nii.gz
# 349  image  CHUM-006__PT.nii.gz
# 350  image  MDA-096__PT.nii.gz
# 351  image  HGJ-039__CT.nii.gz
# 352  image  MDA-157__CT.nii.gz
# 353  image  MDA-016__CT.nii.gz
# 354  image  CHUP-011__PT.nii.gz
# 355  image  CHUV-050__PT.nii.gz
# 356  image  MDA-021__CT.nii.gz
# 357  image  CHUP-026__PT.nii.gz
# 358  image  HMR-011__PT.nii.gz
# 359  image  CHUM-064__PT.nii.gz
# 360  image  MDA-102__CT.nii.gz
# 361  image  MDA-135__CT.nii.gz
# 362  image  CHUM-053__PT.nii.gz
# 363  image  MDA-134__PT.nii.gz
# 364  image  MDA-103__PT.nii.gz
# 365  image  CHUM-065__CT.nii.gz
# 366  image  CHUV-051__CT.nii.gz
# 367  image  MDA-020__PT.nii.gz
# 368  image  CHUP-027__CT.nii.gz
# 369  image  MDA-017__PT.nii.gz
# 370  image  CHUP-010__CT.nii.gz
# 371  image  MDA-156__PT.nii.gz
# 372  image  MDA-097__CT.nii.gz
# 373  image  HGJ-038__PT.nii.gz
# 374  image  CHUM-030__CT.nii.gz
# 375  image  CHUM-007__CT.nii.gz
# 376  image  MDA-161__PT.nii.gz
# 377  image  MDA-183__CT.nii.gz
# 378  image  MDA-042__PT.nii.gz
# 379  image  CHUV-033__CT.nii.gz
# 380  image  CHUS-038__PT.nii.gz
# 381  image  CHUV-004__CT.nii.gz
# 382  image  CHUP-072__CT.nii.gz
# 383  image  MDA-075__PT.nii.gz
# 384  image  HGJ-025__CT.nii.gz
# 385  image  CHUP-058__PT.nii.gz
# 386  image  MDA-068__CT.nii.gz
# 387  image  CHUV-019__PT.nii.gz
# 388  image  MDA-129__CT.nii.gz
# 389  image  HGJ-070__CT.nii.gz
# 390  image  HGJ-092__PT.nii.gz
# 391  image  CHUS-047__CT.nii.gz
# 392  image  CHUM-034__PT.nii.gz
# 393  image  MDA-093__PT.nii.gz
# 394  image  MDA-152__CT.nii.gz
# 395  image  MDA-165__CT.nii.gz
# 396  image  CHUV-037__PT.nii.gz
# 397  image  CHUP-041__PT.nii.gz
# 398  image  MDA-046__CT.nii.gz
# 399  image  MDA-187__PT.nii.gz
# 400  image  MDA-071__CT.nii.gz
# 401  image  MDA-130__CT.nii.gz
# 402  image  HMR-023__PT.nii.gz
# 403  image  CHUM-056__PT.nii.gz
# 404  image  CHUM-061__PT.nii.gz
# 405  image  HMR-014__PT.nii.gz
# 406  image  HGJ-069__CT.nii.gz
# 407  image  MDA-107__CT.nii.gz
# 408  image  MDA-024__CT.nii.gz
# 409  image  CHUP-023__PT.nii.gz
# 410  image  CHUS-069__CT.nii.gz
# 411  image  MDA-013__CT.nii.gz
# 412  image  CHUS-096__CT.nii.gz
# 413  image  HGJ-043__PT.nii.gz
# 414  image  HGJ-074__PT.nii.gz
# 415  image  CHUV-048__CT.nii.gz
# 416  image  CHUS-043__PT.nii.gz
# 417  image  MDA-039__PT.nii.gz
# 418  image  CHUP-009__CT.nii.gz
# 419  image  CHUS-074__PT.nii.gz
# 420  image  CHUM-029__CT.nii.gz
# 421  image  HGJ-016__PT.nii.gz
# 422  image  MDA-178__PT.nii.gz
# 423  image  CHUS-021__PT.nii.gz
# 424  image  CHUS-016__PT.nii.gz
# 425  image  CHUS-020__CT.nii.gz
# 426  image  MDA-179__CT.nii.gz
# 427  image  HGJ-017__CT.nii.gz
# 428  image  CHUP-008__PT.nii.gz
# 429  image  CHUV-049__PT.nii.gz
# 430  image  CHUS-042__CT.nii.gz
# 431  image  MDA-038__CT.nii.gz
# 432  image  CHUS-097__PT.nii.gz
# 433  image  CHUS-068__PT.nii.gz
# 434  image  MDA-012__PT.nii.gz
# 435  image  CHUP-015__CT.nii.gz
# 436  image  MDA-025__PT.nii.gz
# 437  image  CHUP-022__CT.nii.gz
# 438  image  MDA-106__PT.nii.gz
# 439  image  CHUM-060__CT.nii.gz
# 440  image  CHUM-057__CT.nii.gz
# 441  image  MDA-131__PT.nii.gz
# 442  image  MDA-070__PT.nii.gz
# 443  image  CHUV-001__CT.nii.gz
# 444  image  MDA-186__CT.nii.gz
# 445  image  CHUV-036__CT.nii.gz
# 446  image  CHUP-040__CT.nii.gz
# 447  image  MDA-047__PT.nii.gz
# 448  image  CHUM-002__CT.nii.gz
# 449  image  MDA-164__PT.nii.gz
# 450  image  MDA-153__PT.nii.gz
# 451  image  CHUM-035__CT.nii.gz
# 452  image  MDA-092__CT.nii.gz
# 453  image  HMR-040__CT.nii.gz
# 454  image  MDA-142__PT.nii.gz
# 455  image  MDA-083__CT.nii.gz
# 456  image  CHUM-024__CT.nii.gz
# 457  image  CHUM-013__CT.nii.gz
# 458  image  MDA-175__PT.nii.gz
# 459  image  MDA-197__CT.nii.gz
# 460  image  MDA-056__PT.nii.gz
# 461  image  CHUP-051__CT.nii.gz
# 462  image  CHUV-027__CT.nii.gz
# 463  image  CHUV-010__CT.nii.gz
# 464  image  MDA-061__PT.nii.gz
# 465  image  CHUP-066__CT.nii.gz
# 466  image  CHUM-046__CT.nii.gz
# 467  image  MDA-120__PT.nii.gz
# 468  image  MDA-117__PT.nii.gz
# 469  image  HMR-004__CT.nii.gz
# 470  image  CHUV-045__CT.nii.gz
# 471  image  CHUP-033__CT.nii.gz
# 472  image  MDA-034__PT.nii.gz
# 473  image  CHUP-004__CT.nii.gz
# 474  image  MDA-003__PT.nii.gz
# 475  image  HGJ-053__CT.nii.gz
# 476  image  CHUS-086__PT.nii.gz
# 477  image  HGJ-086__PT.nii.gz
# 478  image  MDA-029__CT.nii.gz
# 479  image  CHUS-053__CT.nii.gz
# 480  image  CHUS-064__CT.nii.gz
# 481  image  CHUP-019__PT.nii.gz
# 482  image  CHUM-039__PT.nii.gz
# 483  image  HGJ-031__CT.nii.gz
# 484  image  MDA-168__CT.nii.gz
# 485  image  CHUS-031__CT.nii.gz
# 486  image  MDA-201__CT.nii.gz
# 487  image  CHUS-006__CT.nii.gz
# 488  image  CHUS-007__PT.nii.gz
# 489  image  MDA-200__PT.nii.gz
# 490  image  CHUS-030__PT.nii.gz
# 491  image  HGJ-007__PT.nii.gz
# 492  image  MDA-169__PT.nii.gz
# 493  image  CHUM-038__CT.nii.gz
# 494  image  HGJ-030__PT.nii.gz
# 495  image  CHUS-065__PT.nii.gz
# 496  image  CHUP-018__CT.nii.gz
# 497  image  HGJ-087__CT.nii.gz
# 498  image  MDA-028__PT.nii.gz
# 499  image  CHUS-052__PT.nii.gz
# 500  image  HGJ-065__PT.nii.gz
# 501  image  HGJ-052__PT.nii.gz
# 502  image  CHUS-087__CT.nii.gz
# 503  image  CHUP-005__PT.nii.gz
# 504  image  CHUS-078__CT.nii.gz
# 505  image  CHUV-044__PT.nii.gz
# 506  image  CHUP-032__PT.nii.gz
# 507  image  MDA-035__CT.nii.gz
# 508  image  HMR-005__PT.nii.gz
# 509  image  HGJ-078__CT.nii.gz
# 510  image  MDA-116__CT.nii.gz
# 511  image  MDA-121__CT.nii.gz
# 512  image  CHUM-047__PT.nii.gz
# 513  image  CHUV-011__PT.nii.gz
# 514  image  MDA-060__CT.nii.gz
# 515  image  CHUP-067__PT.nii.gz
# 516  image  MDA-057__CT.nii.gz
# 517  image  CHUP-050__PT.nii.gz
# 518  image  CHUV-026__PT.nii.gz
# 519  image  MDA-196__PT.nii.gz
# 520  image  MDA-174__CT.nii.gz
# 521  image  CHUM-012__PT.nii.gz
# 522  image  MDA-082__PT.nii.gz
# 523  image  MDA-143__CT.nii.gz
# 524  image  MDA-026__PT.nii.gz
# 525  image  HGJ-089__CT.nii.gz
# 526  image  MDA-011__PT.nii.gz
# 527  image  CHUP-016__CT.nii.gz
# 528  image  HMR-021__CT.nii.gz
# 529  image  CHUM-054__CT.nii.gz
# 530  image  CHUS-089__CT.nii.gz
# 531  image  MDA-132__PT.nii.gz
# 532  image  MDA-105__PT.nii.gz
# 533  image  CHUM-063__CT.nii.gz
# 534  image  HMR-016__CT.nii.gz
# 535  image  MDA-185__CT.nii.gz
# 536  image  CHUV-035__CT.nii.gz
# 537  image  CHUP-043__CT.nii.gz
# 538  image  MDA-044__PT.nii.gz
# 539  image  CHUP-074__CT.nii.gz
# 540  image  MDA-073__PT.nii.gz
# 541  image  CHUS-009__PT.nii.gz
# 542  image  CHUV-002__CT.nii.gz
# 543  image  MDA-150__PT.nii.gz
# 544  image  CHUM-036__CT.nii.gz
# 545  image  MDA-091__CT.nii.gz
# 546  image  CHUM-001__CT.nii.gz
# 547  image  MDA-167__PT.nii.gz
# 548  image  MDA-059__CT.nii.gz
# 549  image  CHUV-028__PT.nii.gz
# 550  image  MDA-198__PT.nii.gz
# 551  image  CHUP-069__PT.nii.gz
# 552  image  CHUS-100__CT.nii.gz
# 553  image  CHUS-041__CT.nii.gz
# 554  image  CHUS-076__CT.nii.gz
# 555  image  CHUM-049__PT.nii.gz
# 556  image  CHUS-094__PT.nii.gz
# 557  image  HGJ-076__CT.nii.gz
# 558  image  MDA-118__CT.nii.gz
# 559  image  MDA-119__PT.nii.gz
# 560  image  HGJ-077__PT.nii.gz
# 561  image  CHUM-048__CT.nii.gz
# 562  image  CHUS-095__CT.nii.gz
# 563  image  CHUS-077__PT.nii.gz
# 564  image  CHUS-040__PT.nii.gz
# 565  image  HGJ-015__PT.nii.gz
# 566  image  CHUS-101__PT.nii.gz
# 567  image  CHUS-015__PT.nii.gz
# 568  image  CHUP-068__CT.nii.gz
# 569  image  MDA-199__CT.nii.gz
# 570  image  MDA-058__PT.nii.gz
# 571  image  CHUS-022__PT.nii.gz
# 572  image  CHUV-029__CT.nii.gz
# 573  image  MDA-166__CT.nii.gz
# 574  image  HGJ-008__CT.nii.gz
# 575  image  CHUM-037__PT.nii.gz
# 576  image  MDA-090__PT.nii.gz
# 577  image  MDA-151__CT.nii.gz
# 578  image  CHUP-075__PT.nii.gz
# 579  image  MDA-072__CT.nii.gz
# 580  image  CHUS-008__CT.nii.gz
# 581  image  CHUV-003__PT.nii.gz
# 582  image  CHUV-034__PT.nii.gz
# 583  image  CHUP-042__PT.nii.gz
# 584  image  MDA-045__CT.nii.gz
# 585  image  MDA-184__PT.nii.gz
# 586  image  CHUM-062__PT.nii.gz
# 587  image  MDA-104__CT.nii.gz
# 588  image  MDA-133__CT.nii.gz
# 589  image  HMR-020__PT.nii.gz
# 590  image  CHUM-055__PT.nii.gz
# 591  image  CHUS-088__PT.nii.gz
# 592  image  MDA-010__CT.nii.gz
# 593  image  CHUP-017__PT.nii.gz
# 594  image  MDA-027__CT.nii.gz
# 595  image  CHUP-020__PT.nii.gz
# 596  image  HGJ-088__PT.nii.gz
# 597  image  CHUV-047__PT.nii.gz
# 598  image  MDA-036__CT.nii.gz
# 599  image  CHUP-006__PT.nii.gz
# 600  image  MDA-001__CT.nii.gz
# 601  image  MDA-122__CT.nii.gz
# 602  image  CHUM-044__PT.nii.gz
# 603  image  MDA-115__CT.nii.gz
# 604  image  MDA-054__CT.nii.gz
# 605  image  CHUP-053__PT.nii.gz
# 606  image  CHUV-025__PT.nii.gz
# 607  image  MDA-195__PT.nii.gz
# 608  image  CHUS-019__CT.nii.gz
# 609  image  CHUV-012__PT.nii.gz
# 610  image  MDA-063__CT.nii.gz
# 611  image  CHUP-064__PT.nii.gz
# 612  image  MDA-081__PT.nii.gz
# 613  image  CHUM-026__PT.nii.gz
# 614  image  MDA-140__CT.nii.gz
# 615  image  MDA-177__CT.nii.gz
# 616  image  CHUM-011__PT.nii.gz
# 617  image  MDA-188__CT.nii.gz
# 618  image  CHUS-033__PT.nii.gz
# 619  image  CHUV-038__CT.nii.gz
# 620  image  MDA-049__PT.nii.gz
# 621  image  CHUS-004__PT.nii.gz
# 622  image  CHUS-051__PT.nii.gz
# 623  image  CHUS-066__PT.nii.gz
# 624  image  CHUM-059__CT.nii.gz
# 625  image  MDA-108__PT.nii.gz
# 626  image  HGJ-066__PT.nii.gz
# 627  image  HGJ-067__CT.nii.gz
# 628  image  MDA-109__CT.nii.gz
# 629  image  HGJ-050__CT.nii.gz
# 630  image  CHUM-058__PT.nii.gz
# 631  image  CHUS-085__PT.nii.gz
# 632  image  CHUS-067__CT.nii.gz
# 633  image  HGJ-085__PT.nii.gz
# 634  image  CHUS-050__CT.nii.gz
# 635  image  HGJ-032__CT.nii.gz
# 636  image  CHUS-005__CT.nii.gz
# 637  image  CHUV-039__PT.nii.gz
# 638  image  MDA-048__CT.nii.gz
# 639  image  MDA-189__PT.nii.gz
# 640  image  CHUM-010__CT.nii.gz
# 641  image  HGJ-018__PT.nii.gz
# 642  image  MDA-176__PT.nii.gz
# 643  image  MDA-141__PT.nii.gz
# 644  image  MDA-080__CT.nii.gz
# 645  image  CHUM-027__CT.nii.gz
# 646  image  CHUV-013__CT.nii.gz
# 647  image  MDA-062__PT.nii.gz
# 648  image  CHUP-065__CT.nii.gz
# 649  image  MDA-194__CT.nii.gz
# 650  image  MDA-055__PT.nii.gz
# 651  image  CHUP-052__CT.nii.gz
# 652  image  CHUV-024__CT.nii.gz
# 653  image  MDA-114__PT.nii.gz
# 654  image  CHUM-045__CT.nii.gz
# 655  image  CHUS-098__CT.nii.gz
# 656  image  HMR-030__CT.nii.gz
# 657  image  MDA-123__PT.nii.gz
# 658  image  CHUP-007__CT.nii.gz
# 659  image  CHUV-046__CT.nii.gz
# 660  image  CHUP-030__CT.nii.gz
# 661  image  MDA-037__PT.nii.gz
# 662  image  MDA-158__PT.nii.gz
# 663  image  HGJ-036__PT.nii.gz
# 664  image  MDA-099__CT.nii.gz
# 665  image  CHUS-036__PT.nii.gz
# 666  image  CHUS-081__CT.nii.gz
# 667  image  HMR-029__CT.nii.gz
# 668  image  MDA-019__PT.nii.gz
# 669  image  CHUP-029__CT.nii.gz
# 670  image  HGJ-081__CT.nii.gz
# 671  image  MDA-110__CT.nii.gz
# 672  image  MDA-127__CT.nii.gz
# 673  image  HMR-034__PT.nii.gz
# 674  image  CHUM-041__PT.nii.gz
# 675  image  CHUP-003__PT.nii.gz
# 676  image  MDA-004__CT.nii.gz
# 677  image  CHUP-034__PT.nii.gz
# 678  image  MDA-033__CT.nii.gz
# 679  image  CHUS-049__CT.nii.gz
# 680  image  CHUV-042__PT.nii.gz
# 681  image  MDA-172__CT.nii.gz
# 682  image  CHUM-014__PT.nii.gz
# 683  image  CHUM-023__PT.nii.gz
# 684  image  MDA-084__PT.nii.gz
# 685  image  MDA-145__CT.nii.gz
# 686  image  MDA-066__CT.nii.gz
# 687  image  CHUP-061__PT.nii.gz
# 688  image  CHUV-017__PT.nii.gz
# 689  image  CHUV-020__PT.nii.gz
# 690  image  MDA-051__CT.nii.gz
# 691  image  CHUP-056__PT.nii.gz
# 692  image  MDA-190__PT.nii.gz
# 693  image  MDA-191__CT.nii.gz
# 694  image  CHUV-021__CT.nii.gz
# 695  image  MDA-050__PT.nii.gz
# 696  image  CHUP-057__CT.nii.gz
# 697  image  MDA-067__PT.nii.gz
# 698  image  CHUP-060__CT.nii.gz
# 699  image  CHUV-016__CT.nii.gz
# 700  image  MDA-144__PT.nii.gz
# 701  image  CHUM-022__CT.nii.gz
# 702  image  MDA-085__CT.nii.gz
# 703  image  CHUM-015__CT.nii.gz
# 704  image  MDA-173__PT.nii.gz
# 705  image  CHUP-035__CT.nii.gz
# 706  image  MDA-032__PT.nii.gz
# 707  image  CHUS-048__PT.nii.gz
# 708  image  CHUV-043__CT.nii.gz
# 709  image  CHUP-002__CT.nii.gz
# 710  image  MDA-005__PT.nii.gz
# 711  image  HGJ-048__PT.nii.gz
# 712  image  CHUM-040__CT.nii.gz
# 713  image  MDA-126__PT.nii.gz
# 714  image  MDA-111__PT.nii.gz
# 715  image  CHUS-055__CT.nii.gz
# 716  image  CHUP-028__PT.nii.gz
# 717  image  HGJ-080__PT.nii.gz
# 718  image  MDA-018__CT.nii.gz
# 719  image  CHUS-080__PT.nii.gz
# 720  image  HGJ-055__CT.nii.gz
# 721  image  HMR-028__PT.nii.gz
# 722  image  HGJ-062__CT.nii.gz
# 723  image  HGJ-037__CT.nii.gz
# 724  image  MDA-098__PT.nii.gz
# 725  image  MDA-159__CT.nii.gz
# 726  image  CHUM-008__PT.nii.gz
# 727  image  CHUM-019__PT.nii.gz
# 728  image  HGJ-026__CT.nii.gz
# 729  image  MDA-089__PT.nii.gz
# 730  image  MDA-148__CT.nii.gz
# 731  image  CHUS-026__CT.nii.gz
# 732  image  HGJ-073__CT.nii.gz
# 733  image  CHUS-091__PT.nii.gz
# 734  image  CHUS-073__CT.nii.gz
# 735  image  CHUP-039__PT.nii.gz
# 736  image  HGJ-091__PT.nii.gz
# 737  image  MDA-100__PT.nii.gz
# 738  image  HMR-013__CT.nii.gz
# 739  image  CHUM-051__CT.nii.gz
# 740  image  HMR-024__CT.nii.gz
# 741  image  MDA-137__PT.nii.gz
# 742  image  MDA-014__PT.nii.gz
# 743  image  CHUP-013__CT.nii.gz
# 744  image  CHUV-052__CT.nii.gz
# 745  image  MDA-023__PT.nii.gz
# 746  image  CHUP-024__CT.nii.gz
# 747  image  MDA-162__PT.nii.gz
# 748  image  MDA-155__PT.nii.gz
# 749  image  MDA-094__CT.nii.gz
# 750  image  CHUM-033__CT.nii.gz
# 751  image  CHUV-007__CT.nii.gz
# 752  image  CHUP-071__CT.nii.gz
# 753  image  MDA-076__PT.nii.gz
# 754  image  MDA-180__CT.nii.gz
# 755  image  CHUP-046__CT.nii.gz
# 756  image  MDA-041__PT.nii.gz
# 757  image  CHUV-030__CT.nii.gz
# 758  image  CHUP-047__PT.nii.gz
# 759  image  MDA-040__CT.nii.gz
# 760  image  CHUV-031__PT.nii.gz
# 761  image  MDA-181__PT.nii.gz
# 762  image  CHUV-006__PT.nii.gz
# 763  image  CHUP-070__PT.nii.gz
# 764  image  MDA-077__CT.nii.gz
# 765  image  MDA-095__PT.nii.gz
# 766  image  CHUM-032__PT.nii.gz
# 767  image  MDA-154__CT.nii.gz
# 768  image  MDA-163__CT.nii.gz
# 769  image  CHUS-058__CT.nii.gz
# 770  image  CHUV-053__PT.nii.gz
# 771  image  MDA-022__CT.nii.gz
# 772  image  CHUP-025__PT.nii.gz
# 773  image  MDA-015__CT.nii.gz
# 774  image  CHUP-012__PT.nii.gz
# 775  image  MDA-136__CT.nii.gz
# 776  image  CHUM-050__PT.nii.gz
# 777  image  HGJ-058__CT.nii.gz
# 778  image  HMR-025__PT.nii.gz
# 779  image  HMR-012__PT.nii.gz
# 780  image  MDA-101__CT.nii.gz
# 781  image  CHUP-038__CT.nii.gz
# 782  image  HGJ-090__CT.nii.gz
# 783  image  CHUS-045__PT.nii.gz
# 784  image  CHUS-090__CT.nii.gz
# 785  image  HGJ-072__PT.nii.gz
# 786  image  CHUS-027__PT.nii.gz
# 787  image  CHUS-010__PT.nii.gz
# 788  image  MDA-149__PT.nii.gz
# 789  image  MDA-088__CT.nii.gz
# 790  image  HGJ-010__PT.nii.gz
# 791  image  CHUM-018__CT.nii.gz
# 792  image  CHUS-097__CT.nii.gz
# 793  image  MDA-038__PT.nii.gz
# 794  image  CHUS-042__PT.nii.gz
# 795  image  CHUV-049__CT.nii.gz
# 796  image  CHUP-008__CT.nii.gz
# 797  image  MDA-179__PT.nii.gz
# 798  image  HGJ-017__PT.nii.gz
# 799  image  CHUS-020__PT.nii.gz
# 800  image  MDA-153__CT.nii.gz
# 801  image  HMR-040__PT.nii.gz
# 802  image  MDA-092__PT.nii.gz
# 803  image  CHUM-035__PT.nii.gz
# 804  image  CHUM-002__PT.nii.gz
# 805  image  MDA-164__CT.nii.gz
# 806  image  MDA-186__PT.nii.gz
# 807  image  CHUP-040__PT.nii.gz
# 808  image  MDA-047__CT.nii.gz
# 809  image  CHUV-036__PT.nii.gz
# 810  image  CHUV-001__PT.nii.gz
# 811  image  MDA-070__CT.nii.gz
# 812  image  CHUM-057__PT.nii.gz
# 813  image  MDA-131__CT.nii.gz
# 814  image  MDA-106__CT.nii.gz
# 815  image  CHUM-060__PT.nii.gz
# 816  image  MDA-025__CT.nii.gz
# 817  image  CHUP-022__PT.nii.gz
# 818  image  MDA-012__CT.nii.gz
# 819  image  CHUP-015__PT.nii.gz
# 820  image  CHUS-068__CT.nii.gz
# 821  image  MDA-013__PT.nii.gz
# 822  image  CHUS-069__PT.nii.gz
# 823  image  MDA-024__PT.nii.gz
# 824  image  CHUP-023__CT.nii.gz
# 825  image  HMR-014__CT.nii.gz
# 826  image  HGJ-069__PT.nii.gz
# 827  image  CHUM-061__CT.nii.gz
# 828  image  MDA-107__PT.nii.gz
# 829  image  MDA-130__PT.nii.gz
# 830  image  CHUM-056__CT.nii.gz
# 831  image  HMR-023__CT.nii.gz
# 832  image  MDA-071__PT.nii.gz
# 833  image  CHUP-041__CT.nii.gz
# 834  image  MDA-046__PT.nii.gz
# 835  image  CHUV-037__CT.nii.gz
# 836  image  MDA-187__CT.nii.gz
# 837  image  MDA-165__PT.nii.gz
# 838  image  MDA-093__CT.nii.gz
# 839  image  CHUM-034__CT.nii.gz
# 840  image  MDA-152__PT.nii.gz
# 841  image  CHUS-016__CT.nii.gz
# 842  image  CHUS-021__CT.nii.gz
# 843  image  HGJ-016__CT.nii.gz
# 844  image  MDA-178__CT.nii.gz
# 845  image  CHUM-029__PT.nii.gz
# 846  image  CHUS-074__CT.nii.gz
# 847  image  CHUP-009__PT.nii.gz
# 848  image  MDA-039__CT.nii.gz
# 849  image  CHUS-043__CT.nii.gz
# 850  image  CHUV-048__PT.nii.gz
# 851  image  HGJ-074__CT.nii.gz
# 852  image  HGJ-043__CT.nii.gz
# 853  image  CHUS-096__PT.nii.gz
# 854  image  CHUS-087__PT.nii.gz
# 855  image  HGJ-052__CT.nii.gz
# 856  image  HGJ-065__CT.nii.gz
# 857  image  CHUS-052__CT.nii.gz
# 858  image  MDA-028__CT.nii.gz
# 859  image  HGJ-087__PT.nii.gz
# 860  image  CHUP-018__PT.nii.gz
# 861  image  CHUS-065__CT.nii.gz
# 862  image  HGJ-030__CT.nii.gz
# 863  image  CHUM-038__PT.nii.gz
# 864  image  HGJ-007__CT.nii.gz
# 865  image  MDA-169__CT.nii.gz
# 866  image  CHUS-030__CT.nii.gz
# 867  image  CHUS-007__CT.nii.gz
# 868  image  MDA-200__CT.nii.gz
# 869  image  MDA-082__CT.nii.gz
# 870  image  MDA-143__PT.nii.gz
# 871  image  MDA-174__PT.nii.gz
# 872  image  CHUM-012__CT.nii.gz
# 873  image  CHUV-026__CT.nii.gz
# 874  image  MDA-057__PT.nii.gz
# 875  image  CHUP-050__CT.nii.gz
# 876  image  MDA-196__CT.nii.gz
# 877  image  MDA-060__PT.nii.gz
# 878  image  CHUP-067__CT.nii.gz
# 879  image  CHUV-011__CT.nii.gz
# 880  image  MDA-121__PT.nii.gz
# 881  image  CHUM-047__CT.nii.gz
# 882  image  HMR-005__CT.nii.gz
# 883  image  HGJ-078__PT.nii.gz
# 884  image  MDA-116__PT.nii.gz
# 885  image  CHUP-032__CT.nii.gz
# 886  image  MDA-035__PT.nii.gz
# 887  image  CHUV-044__CT.nii.gz
# 888  image  CHUS-078__PT.nii.gz
# 889  image  CHUP-005__CT.nii.gz
# 890  image  CHUP-004__PT.nii.gz
# 891  image  MDA-003__CT.nii.gz
# 892  image  CHUP-033__PT.nii.gz
# 893  image  MDA-034__CT.nii.gz
# 894  image  CHUV-045__PT.nii.gz
# 895  image  MDA-117__CT.nii.gz
# 896  image  HMR-004__PT.nii.gz
# 897  image  CHUM-046__PT.nii.gz
# 898  image  MDA-120__CT.nii.gz
# 899  image  MDA-061__CT.nii.gz
# 900  image  CHUP-066__PT.nii.gz
# 901  image  CHUV-010__PT.nii.gz
# 902  image  MDA-197__PT.nii.gz
# 903  image  CHUV-027__PT.nii.gz
# 904  image  MDA-056__CT.nii.gz
# 905  image  CHUP-051__PT.nii.gz
# 906  image  CHUM-013__PT.nii.gz
# 907  image  MDA-175__CT.nii.gz
# 908  image  MDA-142__CT.nii.gz
# 909  image  CHUM-024__PT.nii.gz
# 910  image  MDA-083__PT.nii.gz
# 911  image  MDA-201__PT.nii.gz
# 912  image  CHUS-006__PT.nii.gz
# 913  image  CHUS-031__PT.nii.gz
# 914  image  MDA-168__PT.nii.gz
# 915  image  HGJ-031__PT.nii.gz
# 916  image  CHUM-039__CT.nii.gz
# 917  image  CHUP-019__CT.nii.gz
# 918  image  CHUS-064__PT.nii.gz
# 919  image  CHUS-053__PT.nii.gz
# 920  image  MDA-029__PT.nii.gz
# 921  image  HGJ-086__CT.nii.gz
# 922  image  CHUS-086__CT.nii.gz
# 923  image  HGJ-053__PT.nii.gz
# 924  image  CHUV-014__CT.nii.gz
# 925  image  MDA-065__PT.nii.gz
# 926  image  CHUP-062__CT.nii.gz
# 927  image  MDA-052__PT.nii.gz
# 928  image  CHUP-055__CT.nii.gz
# 929  image  CHUS-028__PT.nii.gz
# 930  image  CHUV-023__CT.nii.gz
# 931  image  MDA-193__CT.nii.gz
# 932  image  MDA-171__PT.nii.gz
# 933  image  CHUM-017__CT.nii.gz
# 934  image  HGJ-028__PT.nii.gz
# 935  image  MDA-087__CT.nii.gz
# 936  image  MDA-146__PT.nii.gz
# 937  image  CHUP-000__CT.nii.gz
# 938  image  MDA-007__PT.nii.gz
# 939  image  CHUV-041__CT.nii.gz
# 940  image  CHUP-037__CT.nii.gz
# 941  image  MDA-030__PT.nii.gz
# 942  image  MDA-113__PT.nii.gz
# 943  image  MDA-124__PT.nii.gz
# 944  image  CHUM-042__CT.nii.gz
# 945  image  CHUS-060__CT.nii.gz
# 946  image  HGJ-082__PT.nii.gz
# 947  image  CHUS-057__CT.nii.gz
# 948  image  HGJ-057__CT.nii.gz
# 949  image  MDA-139__CT.nii.gz
# 950  image  MDA-078__CT.nii.gz
# 951  image  CHUV-009__PT.nii.gz
# 952  image  CHUS-035__CT.nii.gz
# 953  image  CHUP-048__PT.nii.gz
# 954  image  HGJ-035__CT.nii.gz
# 955  image  HGJ-034__PT.nii.gz
# 956  image  CHUP-049__CT.nii.gz
# 957  image  MDA-079__PT.nii.gz
# 958  image  CHUS-003__PT.nii.gz
# 959  image  CHUV-008__CT.nii.gz
# 960  image  MDA-138__PT.nii.gz
# 961  image  CHUS-083__CT.nii.gz
# 962  image  HGJ-083__CT.nii.gz
# 963  image  CHUS-056__PT.nii.gz
# 964  image  CHUS-061__PT.nii.gz
# 965  image  CHUM-043__PT.nii.gz
# 966  image  MDA-125__CT.nii.gz
# 967  image  MDA-112__CT.nii.gz
# 968  image  HMR-001__PT.nii.gz
# 969  image  CHUV-040__PT.nii.gz
# 970  image  CHUP-036__PT.nii.gz
# 971  image  MDA-031__CT.nii.gz
# 972  image  CHUP-001__PT.nii.gz
# 973  image  MDA-006__CT.nii.gz
# 974  image  MDA-147__CT.nii.gz
# 975  image  HGJ-029__CT.nii.gz
# 976  image  MDA-086__PT.nii.gz
# 977  image  CHUM-021__PT.nii.gz
# 978  image  CHUM-016__PT.nii.gz
# 979  image  MDA-170__CT.nii.gz
# 980  image  MDA-192__PT.nii.gz
# 981  image  MDA-053__CT.nii.gz
# 982  image  CHUP-054__PT.nii.gz
# 983  image  CHUV-022__PT.nii.gz
# 984  image  CHUV-015__PT.nii.gz
# 985  image  MDA-064__CT.nii.gz
# 986  image  CHUP-063__PT.nii.gz
# 987  image  CHUP-072__PT.nii.gz
# 988  image  MDA-075__CT.nii.gz
# 989  image  CHUV-004__PT.nii.gz
# 990  image  MDA-183__PT.nii.gz
# 991  image  CHUS-038__CT.nii.gz
# 992  image  CHUV-033__PT.nii.gz
# 993  image  MDA-042__CT.nii.gz
# 994  image  CHUM-007__PT.nii.gz
# 995  image  MDA-161__CT.nii.gz
# 996  image  MDA-156__CT.nii.gz
# 997  image  CHUM-030__PT.nii.gz
# 998  image  HGJ-038__CT.nii.gz
# 999  image  MDA-097__PT.nii.gz
# 1000  image  MDA-017__CT.nii.gz
# 1001  image  CHUP-010__PT.nii.gz
# 1002  image  MDA-020__CT.nii.gz
# 1003  image  CHUP-027__PT.nii.gz
# 1004  image  CHUV-051__PT.nii.gz
# 1005  image  MDA-103__CT.nii.gz
# 1006  image  CHUM-065__PT.nii.gz
# 1007  image  MDA-134__CT.nii.gz
# 1008  image  CHUS-047__PT.nii.gz
# 1009  image  HGJ-092__CT.nii.gz
# 1010  image  HGJ-070__PT.nii.gz
# 1011  image  MDA-129__PT.nii.gz
# 1012  image  CHUV-019__CT.nii.gz
# 1013  image  MDA-068__PT.nii.gz
# 1014  image  CHUP-058__CT.nii.gz
# 1015  image  HGJ-025__PT.nii.gz
# 1016  image  HGJ-013__CT.nii.gz
# 1017  image  CHUP-059__PT.nii.gz
# 1018  image  CHUS-013__CT.nii.gz
# 1019  image  CHUV-018__PT.nii.gz
# 1020  image  MDA-069__CT.nii.gz
# 1021  image  HGJ-046__CT.nii.gz
# 1022  image  MDA-128__CT.nii.gz
# 1023  image  HGJ-071__CT.nii.gz
# 1024  image  CHUS-046__CT.nii.gz
# 1025  image  MDA-135__PT.nii.gz
# 1026  image  CHUM-053__CT.nii.gz
# 1027  image  CHUM-064__CT.nii.gz
# 1028  image  HMR-011__CT.nii.gz
# 1029  image  MDA-102__PT.nii.gz
# 1030  image  MDA-021__PT.nii.gz
# 1031  image  CHUP-026__CT.nii.gz
# 1032  image  CHUV-050__CT.nii.gz
# 1033  image  MDA-016__PT.nii.gz
# 1034  image  CHUP-011__CT.nii.gz
# 1035  image  HGJ-039__PT.nii.gz
# 1036  image  MDA-096__CT.nii.gz
# 1037  image  MDA-157__PT.nii.gz
# 1038  image  MDA-160__PT.nii.gz
# 1039  image  CHUM-006__CT.nii.gz
# 1040  image  CHUS-039__PT.nii.gz
# 1041  image  CHUV-032__CT.nii.gz
# 1042  image  CHUP-044__CT.nii.gz
# 1043  image  MDA-043__PT.nii.gz
# 1044  image  MDA-182__CT.nii.gz
# 1045  image  CHUP-073__CT.nii.gz
# 1046  image  MDA-074__PT.nii.gz
# 1047  image  CHUV-005__CT.nii.gz
#              File Name Institute  \
# 0  CHUM-040__PT.nii.gz      CHUM
# 1  CHUP-002__PT.nii.gz      CHUP
# 2  CHUV-043__PT.nii.gz      CHUV
# 3  CHUP-035__PT.nii.gz      CHUP
# 4  CHUM-015__PT.nii.gz      CHUM
#
#                                              spacing             size modality
# 0              (5.46875, 5.46875, 3.269923686981201)  (128, 128, 263)       PT
# 1  (4.0728302001953125, 4.0728302001953125, 2.026...  (200, 200, 481)       PT
# 2           (2.734375, 2.734375, 3.2699999809265137)  (256, 256, 335)       PT
# 3  (4.0728302001953125, 4.0728302001953125, 2.026...  (200, 200, 481)       PT
# 4                                    (4.0, 4.0, 4.0)   (144, 144, 87)       PT

# %% [markdown]
# **concatenate both data frames**

# %%
images_df = pd.concat([ct_df, pt_df])

# %%
images_df.groupby(by=['Institute', 'modality']).count()
# Out:
#                     File Name  spacing  size
# Institute modality
# CHUM      CT               56       56    56
#           PT               56       56    56
# CHUP      CT               72       72    72
#           PT               72       72    72
# CHUS      CT               72       72    72
#           PT               72       72    72
# CHUV      CT               53       53    53
#           PT               53       53    53
# HGJ-      CT               55       55    55
#           PT               55       55    55
# HMR-      CT               18       18    18
#           PT               18       18    18
# MDA-      CT              198      198   198
#           PT              198      198   198

# %% [markdown]
# **Add Some Columns**

# %%
# add spacing x,y,z coordinates
images_df['spacing_x'] = images_df['spacing'].apply(lambda x: x[1:-1].split(',')[0]).astype(float)
images_df['spacing_y'] = images_df['spacing'].apply(lambda x: x[1:-1].split(',')[1]).astype(float)
images_df['spacing_z'] = images_df['spacing'].apply(lambda x: x[1:-1].split(',')[2]).astype(float)

# %%
# fix institute
def fix_institute(institute):
    if institute.endswith('-'):
        return institute.split('-')[0]
    return institute

# %%
images_df['Institute'] = images_df['Institute'].apply(lambda x: fix_institute(x))

# %%
images_df.tail()
# Out:
#                File Name Institute                                 spacing  \
# 519   MDA-157__PT.nii.gz       MDA  (5.46875, 5.46875, 3.2701196670532227)
# 520   MDA-160__PT.nii.gz       MDA  (5.46875, 5.46875, 3.2699999809265137)
# 521  CHUS-039__PT.nii.gz      CHUS                         (4.0, 4.0, 4.0)
# 522   MDA-043__PT.nii.gz       MDA  (5.46875, 5.46875, 3.2699999809265137)
# 523   MDA-074__PT.nii.gz       MDA              (4.296875, 4.296875, 4.25)
#
#                 size modality  spacing_x  spacing_y  spacing_z
# 519  (128, 128, 335)       PT   5.468750   5.468750    3.27012
# 520  (128, 128, 127)       PT   5.468750   5.468750    3.27000
# 521  (144, 144, 255)       PT   4.000000   4.000000    4.00000
# 522  (128, 128, 127)       PT   5.468750   5.468750    3.27000
# 523  (128, 128, 259)       PT   4.296875   4.296875    4.25000

# %%
spacing_info = images_df.groupby(by=['Institute', 'modality'])[['spacing_x', 'spacing_y', 'spacing_z']].mean()

# %%
image_count_info = images_df.groupby(by=['Institute', 'modality'])[['File Name']].count()

# %%
information = pd.concat([spacing_info, image_count_info], axis=1)
information
# Out:
#                     spacing_x  spacing_y  spacing_z  File Name
# Institute modality
# CHUM      CT         0.987026   0.987026   1.974107         56
#           PT         4.009766   4.009766   3.805447         56
# CHUP      CT         0.976562   0.976562   1.506944         72
#           PT         4.072830   4.072830   2.027000         72
# CHUS      CT         1.165093   1.165093   2.819444         72
#           PT         4.000000   4.000000   4.000000         72
# CHUV      CT         1.249263   1.249263   3.033962         53
#           PT         2.844929   2.844929   3.362453         53
# HGJ       CT         0.976562   0.976562   3.270000         55
#           PT         3.536932   3.536932   3.270225         55
# HMR       CT         1.063368   1.063368   3.270000         18
#           PT         3.949653   3.949653   3.270117         18
# MDA       CT         0.989828   0.989828   3.257473        198
#           PT         5.112321   5.112321   3.278259        198

# %% [markdown]
# # Select Source and Target Datasets

# %%
source = images_df[images_df['Institute']=='MDA']

# %%
target1 =  images_df[images_df['Institute']=='CHUP']
target2 = images_df[images_df['Institute']=='CHUS']

# %%
source.head()
# Out:
#             File Name Institute  \
# 0  MDA-111__CT.nii.gz       MDA
# 2  MDA-126__CT.nii.gz       MDA
# 3  MDA-005__CT.nii.gz       MDA
# 5  MDA-032__CT.nii.gz       MDA
# 6  MDA-173__CT.nii.gz       MDA
#
#                                              spacing             size  \
# 0                        (0.9765625, 0.9765625, 5.0)  (512, 512, 195)
# 2  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 127)
# 3  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 267)
# 5  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 267)
# 6  (0.9765620231628418, 0.9765620231628418, 3.269...   (512, 512, 91)
#
#   modality  spacing_x  spacing_y  spacing_z
# 0       CT   0.976562   0.976562       5.00
# 2       CT   0.976562   0.976562       3.27
# 3       CT   0.976562   0.976562       3.27
# 5       CT   0.976562   0.976562       3.27
# 6       CT   0.976562   0.976562       3.27

# %%
source['label_name'] = source['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
# Out:
# /var/folders/wg/_bw301w169bd2mdb38l8r5j80000gn/T/ipykernel_48079/746426316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   source['label_name'] = source['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))

# %%
source.head()
# Out:
#             File Name Institute  \
# 0  MDA-111__CT.nii.gz       MDA
# 2  MDA-126__CT.nii.gz       MDA
# 3  MDA-005__CT.nii.gz       MDA
# 5  MDA-032__CT.nii.gz       MDA
# 6  MDA-173__CT.nii.gz       MDA
#
#                                              spacing             size  \
# 0                        (0.9765625, 0.9765625, 5.0)  (512, 512, 195)
# 2  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 127)
# 3  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 267)
# 5  (0.9765620231628418, 0.9765620231628418, 3.269...  (512, 512, 267)
# 6  (0.9765620231628418, 0.9765620231628418, 3.269...   (512, 512, 91)
#
#   modality  spacing_x  spacing_y  spacing_z      label_name
# 0       CT   0.976562   0.976562       5.00  MDA-111.nii.gz
# 2       CT   0.976562   0.976562       3.27  MDA-126.nii.gz
# 3       CT   0.976562   0.976562       3.27  MDA-005.nii.gz
# 5       CT   0.976562   0.976562       3.27  MDA-032.nii.gz
# 6       CT   0.976562   0.976562       3.27  MDA-173.nii.gz

# %%
source['label_name'].nunique()
# Out:
# 198

# %%
source['File Name'].nunique()
# Out:
# 396

# %%
target1['label_name'] = target1['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
target2['label_name'] = target2['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
# Out:
# /var/folders/wg/_bw301w169bd2mdb38l8r5j80000gn/T/ipykernel_48079/1017298327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target1['label_name'] = target1['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
# /var/folders/wg/_bw301w169bd2mdb38l8r5j80000gn/T/ipykernel_48079/1017298327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target2['label_name'] = target2['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))

# %% [markdown]
# ### create CSV list of source and targets

# %%
# choose where to save the images 
original_folder = '../../datasets/ADDA/original'

# %%
source[['File Name', 'label_name']].to_csv(os.path.join(original_folder, 'source.csv'),
                           header=True, index=False)

# %%
target1[['File Name', 'label_name']].to_csv(os.path.join(original_folder, 'target1.csv'),
                           header=True, index=False)

# %%
target2[['File Name', 'label_name']].to_csv(os.path.join(original_folder, 'target2.csv'),
                           header=True, index=False)

# %%
source_list = pd.read_csv(os.path.join(original_folder, 'source.csv'))
source_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   396 non-null    object
#  1   label_name  396 non-null    object
# dtypes: object(2)
# memory usage: 6.3+ KB

# %%
target1_list = pd.read_csv(os.path.join(original_folder, 'target1.csv'))
target1_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   144 non-null    object
#  1   label_name  144 non-null    object
# dtypes: object(2)
# memory usage: 2.4+ KB

# %%
target2_list = pd.read_csv(os.path.join(original_folder, 'target2.csv'))
target2_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   144 non-null    object
#  1   label_name  144 non-null    object
# dtypes: object(2)
# memory usage: 2.4+ KB

# %%
def copy_images(df, src_folder, trgt_folder, what):
    if what == 'images':
        col = 'File Name'
    elif what == 'labels':
        col = 'label_name'
    else:
        return 


    for img in df[col]:
        img_src = os.path.join(src_folder,img)
        img_trgt = os.path.join(trgt_folder+f'/{what}',img)

        shutil.copy(img_src, img_trgt)
    
    if what == 'labels':
        print(f'copied {df[col].nunique()} files')
    
    else:
        print(f'copied {df[col].shape[0]} files')

# %%
copy_images(source_list, root_image_folder, original_folder, 'images')
# Out:
# copied 396 files

# %%
copy_images(source_list, root_labels_folder, original_folder, 'labels')
# Out:
# copied 198 files

# %%
copy_images(target1_list, root_image_folder, original_folder, 'images')
# Out:
# copied 144 files

# %%
copy_images(target1_list, root_labels_folder, original_folder, 'labels')
# Out:
# copied 72 files

# %%
copy_images(target2_list, root_image_folder, original_folder, 'images')
# Out:
# copied 144 files

# %%
copy_images(target2_list, root_labels_folder, original_folder, 'labels')
# Out:
# copied 72 files

# %% [markdown]
# # Test and Train Split

# %%
src_lbl_names = source['label_name']

# %%
src_ct_names = source['label_name'].apply(lambda x: x.replace('.nii.gz', '__CT.nii.gz'))

# %%
src_pt_names = source['label_name'].apply(lambda x: x.replace('.nii.gz', '__PT.nii.gz'))

# %%
df = pd.DataFrame({'ct_image':src_ct_names,
                  'pt_image':src_pt_names,
                  'label':src_lbl_names})
df.head()
# Out:
#              ct_image            pt_image           label
# 0  MDA-111__CT.nii.gz  MDA-111__PT.nii.gz  MDA-111.nii.gz
# 2  MDA-126__CT.nii.gz  MDA-126__PT.nii.gz  MDA-126.nii.gz
# 3  MDA-005__CT.nii.gz  MDA-005__PT.nii.gz  MDA-005.nii.gz
# 5  MDA-032__CT.nii.gz  MDA-032__PT.nii.gz  MDA-032.nii.gz
# 6  MDA-173__CT.nii.gz  MDA-173__PT.nii.gz  MDA-173.nii.gz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 396 entries, 0 to 523
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ct_image  396 non-null    object
#  1   pt_image  396 non-null    object
#  2   label     396 non-null    object
# dtypes: object(3)
# memory usage: 12.4+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
# First, split into training (60%) and temporary (40%)
source_train, temp_df = train_test_split(df, test_size=0.3, random_state=42)

# Then, split the temporary set into validation (20%) and testing (20%)
source_valid, source_test = train_test_split(temp_df, test_size=0.5, random_state=42)


print('got: ')
print(f'{source_train.shape[0]} training images ')
print(f'{source_valid.shape[0]} validation images ')
print(f'{source_test.shape[0]} testing images ')
# Out:
# got:
# 138 training images
# 30 validation images
# 30 testing images

# %%
# save dataframe info
source_train.to_csv(os.path.join(original_folder, 'source_train.csv'), index=False)
source_valid.to_csv(os.path.join(original_folder, 'source_valid.csv'), index=False)
source_test.to_csv(os.path.join(original_folder, 'source_test.csv'), index=False)

# %% [markdown]
# ### Target 1

# %%
trgt1_lbl_names = target1['label_name']

# %%
trgt1_ct_names = target1['label_name'].apply(lambda x: x.replace('.nii.gz', '__CT.nii.gz'))

# %%
trgt1_pt_names = target1['label_name'].apply(lambda x: x.replace('.nii.gz', '__PT.nii.gz'))

# %%
df = pd.DataFrame({'ct_image':trgt1_ct_names,
                  'pt_image':trgt1_pt_names,
                  'label':trgt1_lbl_names})
df.head()
# Out:
#                ct_image             pt_image            label
# 15  CHUP-028__CT.nii.gz  CHUP-028__PT.nii.gz  CHUP-028.nii.gz
# 20  CHUP-056__CT.nii.gz  CHUP-056__PT.nii.gz  CHUP-056.nii.gz
# 24  CHUP-061__CT.nii.gz  CHUP-061__PT.nii.gz  CHUP-061.nii.gz
# 29  CHUP-034__CT.nii.gz  CHUP-034__PT.nii.gz  CHUP-034.nii.gz
# 30  CHUP-003__CT.nii.gz  CHUP-003__PT.nii.gz  CHUP-003.nii.gz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 15 to 512
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ct_image  144 non-null    object
#  1   pt_image  144 non-null    object
#  2   label     144 non-null    object
# dtypes: object(3)
# memory usage: 4.5+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 15 to 522
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ct_image  72 non-null     object
#  1   pt_image  72 non-null     object
#  2   label     72 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB

# %%
# First, split into training (60%) and temporary (40%)
trgt1_train, temp_df = train_test_split(df, test_size=0.3, random_state=42)

# Then, split the temporary set into validation (20%) and testing (20%)
trgt1_valid, trgt1_test = train_test_split(temp_df, test_size=0.5, random_state=42)


print('got: ')
print(f'{trgt1_train.shape[0]} training images ')
print(f'{trgt1_valid.shape[0]} validation images ')
print(f'{trgt1_test.shape[0]} testing images ')
# Out:
# got:
# 50 training images
# 11 validation images
# 11 testing images

# %%
# save dataframe info
trgt1_train.to_csv(os.path.join(original_folder, 'target1(CHUP)_train.csv'), index=False)
trgt1_valid.to_csv(os.path.join(original_folder, 'target1(CHUP)_valid.csv'), index=False)
trgt1_test.to_csv(os.path.join(original_folder, 'target1(CHUP)_test.csv'), index=False)

# %% [markdown]
# ### Target 2

# %%
trgt2_lbl_names = target2['label_name']

# %%
trgt2_ct_names = target2['label_name'].apply(lambda x: x.replace('.nii.gz', '__CT.nii.gz'))

# %%
trgt2_pt_names = target2['label_name'].apply(lambda x: x.replace('.nii.gz', '__PT.nii.gz'))

# %%
df = pd.DataFrame({'ct_image':trgt2_ct_names,
                  'pt_image':trgt2_pt_names,
                  'label':trgt2_lbl_names})
df.head()
# Out:
#                ct_image             pt_image            label
# 4   CHUS-048__CT.nii.gz  CHUS-048__PT.nii.gz  CHUS-048.nii.gz
# 13  CHUS-080__CT.nii.gz  CHUS-080__PT.nii.gz  CHUS-080.nii.gz
# 17  CHUS-036__CT.nii.gz  CHUS-036__PT.nii.gz  CHUS-036.nii.gz
# 48  CHUS-010__CT.nii.gz  CHUS-010__PT.nii.gz  CHUS-010.nii.gz
# 49  CHUS-027__CT.nii.gz  CHUS-027__PT.nii.gz  CHUS-027.nii.gz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 4 to 521
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ct_image  144 non-null    object
#  1   pt_image  144 non-null    object
#  2   label     144 non-null    object
# dtypes: object(3)
# memory usage: 4.5+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 4 to 510
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ct_image  72 non-null     object
#  1   pt_image  72 non-null     object
#  2   label     72 non-null     object
# dtypes: object(3)
# memory usage: 2.2+ KB

# %%
# First, split into training (60%) and temporary (40%)
trgt2_train, temp_df = train_test_split(df, test_size=0.3, random_state=42)

# Then, split the temporary set into validation (20%) and testing (20%)
trgt2_valid, trgt2_test = train_test_split(temp_df, test_size=0.5, random_state=42)


print('got: ')
print(f'{trgt2_train.shape[0]} training images ')
print(f'{trgt2_valid.shape[0]} validation images ')
print(f'{trgt2_test.shape[0]} testing images ')
# Out:
# got:
# 50 training images
# 11 validation images
# 11 testing images

# %%
# save dataframe info
trgt2_train.to_csv(os.path.join(original_folder, 'target2(CHUS)_train.csv'), index=False)
trgt2_valid.to_csv(os.path.join(original_folder, 'target2(CHUS)_valid.csv'), index=False)
trgt2_test.to_csv(os.path.join(original_folder, 'target2(CHUS)_test.csv'), index=False)

# %% [markdown]
# # Get resampled dataset info

# %%
# !pwd
# Out:
# /Users/ahmad/Desktop/cloud_projects/nii_data/notebooks

# %%
# find all the data thats available
resampled_root_folder = '../../datasets/ADDA/resampled/'
resampled_root_image_folder = os.path.join(resampled_root_folder, 'images')
resampled_root_labels_folder = os.path.join(resampled_root_folder, 'labels')

# %%
print(f'images folder has {len(os.listdir(resampled_root_image_folder))} images')
print(f'images folder has {len(os.listdir(resampled_root_labels_folder))} labels')
# Out:
# images folder has 684 images
# images folder has 342 labels

# %%
def extract_institute(file_name):
    # Assuming the institute name is the first 4 characters of the file name
    return file_name[:4]

# %%
def generate_summary(folder_path, img_type):
    # Initialize empty lists to store file names and institutes
    file_names = []
    institutes = []
    image_spacings = []
    image_sizes = []


    # Traverse the folder and its subdirectories
    for i, file_name in enumerate(os.listdir(folder_path)):
        
        if file_name.endswith(f'__{img_type}.nii.gz'): # or file_name.endswith('__PT.nii.gz'):
            print(i, ' image ', file_name)
            # Extract the institute name from the file name
            institute_name = extract_institute(file_name)

            # Append file name and institute name to the lists
            file_names.append(file_name)
            institutes.append(institute_name)

            # get image information
            selected_image = sitk.ReadImage(os.path.join(folder_path, file_name))
            image_spacings.append(str(selected_image.GetSpacing()))
            image_sizes.append(str(selected_image.GetSize()))

    # Create a DataFrame to store the summary
    summary_df = pd.DataFrame({'File Name': file_names, 
                               'Institute': institutes, 
                               'spacing': image_spacings, 
                               'size': image_sizes})
    
    
    # add type column 
    summary_df['modality'] = [img_type for x in range(summary_df.shape[0])]
    
    
    return summary_df

# %%
ct_df_res = generate_summary(resampled_root_image_folder, 'CT')
# Out:
# 0  image  MDA-111__CT.nii.gz
# 1  image  MDA-126__CT.nii.gz
# 3  image  MDA-005__CT.nii.gz
# 4  image  CHUS-048__CT.nii.gz
# 6  image  MDA-032__CT.nii.gz
# 7  image  MDA-173__CT.nii.gz
# 8  image  MDA-144__CT.nii.gz
# 10  image  MDA-067__CT.nii.gz
# 13  image  MDA-050__CT.nii.gz
# 15  image  MDA-098__CT.nii.gz
# 17  image  CHUS-080__CT.nii.gz
# 19  image  CHUP-028__CT.nii.gz
# 22  image  MDA-019__CT.nii.gz
# 24  image  CHUS-036__CT.nii.gz
# 25  image  MDA-158__CT.nii.gz
# 28  image  CHUP-056__CT.nii.gz
# 29  image  MDA-190__CT.nii.gz
# 31  image  CHUP-061__CT.nii.gz
# 32  image  MDA-084__CT.nii.gz
# 36  image  CHUP-034__CT.nii.gz
# 38  image  CHUP-003__CT.nii.gz
# 45  image  CHUP-012__CT.nii.gz
# 47  image  CHUP-025__CT.nii.gz
# 50  image  MDA-095__CT.nii.gz
# 52  image  CHUP-070__CT.nii.gz
# 54  image  CHUP-047__CT.nii.gz
# 56  image  MDA-181__CT.nii.gz
# 57  image  MDA-149__CT.nii.gz
# 59  image  CHUS-010__CT.nii.gz
# 60  image  CHUS-027__CT.nii.gz
# 62  image  CHUS-045__CT.nii.gz
# 64  image  CHUP-039__CT.nii.gz
# 66  image  CHUS-091__CT.nii.gz
# 68  image  MDA-089__CT.nii.gz
# 72  image  MDA-041__CT.nii.gz
# 74  image  MDA-076__CT.nii.gz
# 75  image  MDA-155__CT.nii.gz
# 77  image  MDA-162__CT.nii.gz
# 78  image  MDA-023__CT.nii.gz
# 80  image  MDA-014__CT.nii.gz
# 82  image  MDA-137__CT.nii.gz
# 83  image  MDA-100__CT.nii.gz
# 85  image  CHUS-022__CT.nii.gz
# 86  image  MDA-058__CT.nii.gz
# 88  image  CHUS-015__CT.nii.gz
# 89  image  CHUS-101__CT.nii.gz
# 90  image  CHUS-040__CT.nii.gz
# 91  image  CHUS-077__CT.nii.gz
# 93  image  MDA-119__CT.nii.gz
# 95  image  CHUP-020__CT.nii.gz
# 97  image  CHUP-017__CT.nii.gz
# 99  image  CHUS-088__CT.nii.gz
# 101  image  CHUP-042__CT.nii.gz
# 103  image  MDA-184__CT.nii.gz
# 105  image  CHUP-075__CT.nii.gz
# 107  image  MDA-090__CT.nii.gz
# 110  image  MDA-167__CT.nii.gz
# 111  image  MDA-150__CT.nii.gz
# 113  image  CHUS-009__CT.nii.gz
# 115  image  MDA-073__CT.nii.gz
# 118  image  MDA-044__CT.nii.gz
# 119  image  MDA-105__CT.nii.gz
# 121  image  MDA-132__CT.nii.gz
# 122  image  MDA-011__CT.nii.gz
# 124  image  MDA-026__CT.nii.gz
# 126  image  CHUS-094__CT.nii.gz
# 130  image  CHUP-069__CT.nii.gz
# 132  image  MDA-198__CT.nii.gz
# 134  image  MDA-189__CT.nii.gz
# 138  image  CHUS-085__CT.nii.gz
# 141  image  MDA-037__CT.nii.gz
# 144  image  MDA-123__CT.nii.gz
# 145  image  MDA-114__CT.nii.gz
# 147  image  MDA-055__CT.nii.gz
# 149  image  MDA-062__CT.nii.gz
# 151  image  MDA-141__CT.nii.gz
# 153  image  MDA-176__CT.nii.gz
# 155  image  MDA-081__CT.nii.gz
# 158  image  CHUP-064__CT.nii.gz
# 161  image  CHUP-053__CT.nii.gz
# 162  image  MDA-195__CT.nii.gz
# 165  image  CHUP-006__CT.nii.gz
# 168  image  MDA-108__CT.nii.gz
# 169  image  CHUS-066__CT.nii.gz
# 170  image  CHUS-051__CT.nii.gz
# 171  image  CHUS-004__CT.nii.gz
# 173  image  MDA-049__CT.nii.gz
# 174  image  CHUS-033__CT.nii.gz
# 175  image  CHUS-061__CT.nii.gz
# 176  image  CHUS-056__CT.nii.gz
# 177  image  MDA-138__CT.nii.gz
# 179  image  CHUS-003__CT.nii.gz
# 180  image  MDA-079__CT.nii.gz
# 183  image  CHUP-063__CT.nii.gz
# 184  image  MDA-192__CT.nii.gz
# 186  image  CHUP-054__CT.nii.gz
# 189  image  MDA-086__CT.nii.gz
# 190  image  CHUP-001__CT.nii.gz
# 192  image  CHUP-036__CT.nii.gz
# 196  image  MDA-124__CT.nii.gz
# 197  image  MDA-113__CT.nii.gz
# 199  image  MDA-030__CT.nii.gz
# 201  image  MDA-007__CT.nii.gz
# 203  image  MDA-146__CT.nii.gz
# 204  image  MDA-171__CT.nii.gz
# 205  image  CHUS-028__CT.nii.gz
# 206  image  MDA-052__CT.nii.gz
# 209  image  MDA-065__CT.nii.gz
# 211  image  CHUP-048__CT.nii.gz
# 221  image  CHUP-059__CT.nii.gz
# 223  image  MDA-074__CT.nii.gz
# 225  image  MDA-043__CT.nii.gz
# 226  image  CHUS-039__CT.nii.gz
# 228  image  MDA-160__CT.nii.gz
# 230  image  MDA-157__CT.nii.gz
# 231  image  MDA-016__CT.nii.gz
# 233  image  MDA-021__CT.nii.gz
# 235  image  MDA-102__CT.nii.gz
# 236  image  MDA-135__CT.nii.gz
# 240  image  CHUP-027__CT.nii.gz
# 242  image  CHUP-010__CT.nii.gz
# 244  image  MDA-097__CT.nii.gz
# 246  image  MDA-183__CT.nii.gz
# 249  image  CHUP-072__CT.nii.gz
# 252  image  MDA-068__CT.nii.gz
# 253  image  MDA-129__CT.nii.gz
# 254  image  CHUS-047__CT.nii.gz
# 256  image  MDA-152__CT.nii.gz
# 257  image  MDA-165__CT.nii.gz
# 259  image  MDA-046__CT.nii.gz
# 261  image  MDA-071__CT.nii.gz
# 262  image  MDA-130__CT.nii.gz
# 263  image  MDA-107__CT.nii.gz
# 264  image  MDA-024__CT.nii.gz
# 266  image  CHUS-069__CT.nii.gz
# 267  image  MDA-013__CT.nii.gz
# 268  image  CHUS-096__CT.nii.gz
# 271  image  CHUP-009__CT.nii.gz
# 276  image  CHUS-020__CT.nii.gz
# 277  image  MDA-179__CT.nii.gz
# 279  image  CHUS-042__CT.nii.gz
# 280  image  MDA-038__CT.nii.gz
# 284  image  CHUP-015__CT.nii.gz
# 286  image  CHUP-022__CT.nii.gz
# 290  image  MDA-186__CT.nii.gz
# 291  image  CHUP-040__CT.nii.gz
# 295  image  MDA-092__CT.nii.gz
# 297  image  MDA-083__CT.nii.gz
# 299  image  MDA-197__CT.nii.gz
# 301  image  CHUP-051__CT.nii.gz
# 303  image  CHUP-066__CT.nii.gz
# 306  image  CHUP-033__CT.nii.gz
# 308  image  CHUP-004__CT.nii.gz
# 311  image  MDA-029__CT.nii.gz
# 312  image  CHUS-053__CT.nii.gz
# 313  image  CHUS-064__CT.nii.gz
# 315  image  MDA-168__CT.nii.gz
# 316  image  CHUS-031__CT.nii.gz
# 317  image  MDA-201__CT.nii.gz
# 318  image  CHUS-006__CT.nii.gz
# 324  image  CHUP-018__CT.nii.gz
# 327  image  CHUS-087__CT.nii.gz
# 329  image  CHUS-078__CT.nii.gz
# 331  image  MDA-035__CT.nii.gz
# 332  image  MDA-116__CT.nii.gz
# 333  image  MDA-121__CT.nii.gz
# 334  image  MDA-060__CT.nii.gz
# 336  image  MDA-057__CT.nii.gz
# 339  image  MDA-174__CT.nii.gz
# 341  image  MDA-143__CT.nii.gz
# 344  image  CHUP-016__CT.nii.gz
# 345  image  CHUS-089__CT.nii.gz
# 348  image  MDA-185__CT.nii.gz
# 349  image  CHUP-043__CT.nii.gz
# 351  image  CHUP-074__CT.nii.gz
# 355  image  MDA-091__CT.nii.gz
# 357  image  MDA-059__CT.nii.gz
# 360  image  CHUS-100__CT.nii.gz
# 361  image  CHUS-041__CT.nii.gz
# 362  image  CHUS-076__CT.nii.gz
# 364  image  MDA-118__CT.nii.gz
# 366  image  CHUS-095__CT.nii.gz
# 371  image  CHUP-068__CT.nii.gz
# 372  image  MDA-199__CT.nii.gz
# 375  image  MDA-166__CT.nii.gz
# 377  image  MDA-151__CT.nii.gz
# 379  image  MDA-072__CT.nii.gz
# 380  image  CHUS-008__CT.nii.gz
# 382  image  MDA-045__CT.nii.gz
# 384  image  MDA-104__CT.nii.gz
# 385  image  MDA-133__CT.nii.gz
# 387  image  MDA-010__CT.nii.gz
# 389  image  MDA-027__CT.nii.gz
# 391  image  MDA-036__CT.nii.gz
# 393  image  MDA-001__CT.nii.gz
# 394  image  MDA-122__CT.nii.gz
# 395  image  MDA-115__CT.nii.gz
# 396  image  MDA-054__CT.nii.gz
# 399  image  CHUS-019__CT.nii.gz
# 400  image  MDA-063__CT.nii.gz
# 403  image  MDA-140__CT.nii.gz
# 404  image  MDA-177__CT.nii.gz
# 405  image  MDA-188__CT.nii.gz
# 412  image  MDA-109__CT.nii.gz
# 414  image  CHUS-067__CT.nii.gz
# 415  image  CHUS-050__CT.nii.gz
# 416  image  CHUS-005__CT.nii.gz
# 417  image  MDA-048__CT.nii.gz
# 421  image  MDA-080__CT.nii.gz
# 423  image  CHUP-065__CT.nii.gz
# 424  image  MDA-194__CT.nii.gz
# 426  image  CHUP-052__CT.nii.gz
# 428  image  CHUS-098__CT.nii.gz
# 430  image  CHUP-007__CT.nii.gz
# 431  image  CHUP-030__CT.nii.gz
# 434  image  MDA-099__CT.nii.gz
# 436  image  CHUS-081__CT.nii.gz
# 438  image  CHUP-029__CT.nii.gz
# 439  image  MDA-110__CT.nii.gz
# 440  image  MDA-127__CT.nii.gz
# 442  image  MDA-004__CT.nii.gz
# 444  image  MDA-033__CT.nii.gz
# 445  image  CHUS-049__CT.nii.gz
# 446  image  MDA-172__CT.nii.gz
# 448  image  MDA-145__CT.nii.gz
# 449  image  MDA-066__CT.nii.gz
# 451  image  MDA-051__CT.nii.gz
# 454  image  MDA-191__CT.nii.gz
# 456  image  CHUP-057__CT.nii.gz
# 458  image  CHUP-060__CT.nii.gz
# 460  image  MDA-085__CT.nii.gz
# 462  image  CHUP-035__CT.nii.gz
# 465  image  CHUP-002__CT.nii.gz
# 469  image  CHUS-055__CT.nii.gz
# 471  image  MDA-018__CT.nii.gz
# 474  image  MDA-159__CT.nii.gz
# 476  image  MDA-148__CT.nii.gz
# 477  image  CHUS-026__CT.nii.gz
# 479  image  CHUS-073__CT.nii.gz
# 484  image  CHUP-013__CT.nii.gz
# 486  image  CHUP-024__CT.nii.gz
# 489  image  MDA-094__CT.nii.gz
# 490  image  CHUP-071__CT.nii.gz
# 492  image  MDA-180__CT.nii.gz
# 493  image  CHUP-046__CT.nii.gz
# 496  image  MDA-040__CT.nii.gz
# 499  image  MDA-077__CT.nii.gz
# 501  image  MDA-154__CT.nii.gz
# 502  image  MDA-163__CT.nii.gz
# 503  image  CHUS-058__CT.nii.gz
# 504  image  MDA-022__CT.nii.gz
# 506  image  MDA-015__CT.nii.gz
# 508  image  MDA-136__CT.nii.gz
# 509  image  MDA-101__CT.nii.gz
# 510  image  CHUP-038__CT.nii.gz
# 512  image  CHUS-090__CT.nii.gz
# 516  image  MDA-088__CT.nii.gz
# 517  image  CHUS-097__CT.nii.gz
# 520  image  CHUP-008__CT.nii.gz
# 523  image  MDA-153__CT.nii.gz
# 525  image  MDA-164__CT.nii.gz
# 528  image  MDA-047__CT.nii.gz
# 529  image  MDA-070__CT.nii.gz
# 530  image  MDA-131__CT.nii.gz
# 531  image  MDA-106__CT.nii.gz
# 532  image  MDA-025__CT.nii.gz
# 534  image  MDA-012__CT.nii.gz
# 536  image  CHUS-068__CT.nii.gz
# 540  image  CHUP-023__CT.nii.gz
# 544  image  CHUP-041__CT.nii.gz
# 546  image  MDA-187__CT.nii.gz
# 548  image  MDA-093__CT.nii.gz
# 550  image  CHUS-016__CT.nii.gz
# 551  image  CHUS-021__CT.nii.gz
# 552  image  MDA-178__CT.nii.gz
# 553  image  CHUS-074__CT.nii.gz
# 555  image  MDA-039__CT.nii.gz
# 556  image  CHUS-043__CT.nii.gz
# 559  image  CHUS-052__CT.nii.gz
# 560  image  MDA-028__CT.nii.gz
# 562  image  CHUS-065__CT.nii.gz
# 563  image  MDA-169__CT.nii.gz
# 564  image  CHUS-030__CT.nii.gz
# 565  image  CHUS-007__CT.nii.gz
# 566  image  MDA-200__CT.nii.gz
# 567  image  MDA-082__CT.nii.gz
# 571  image  CHUP-050__CT.nii.gz
# 572  image  MDA-196__CT.nii.gz
# 574  image  CHUP-067__CT.nii.gz
# 577  image  CHUP-032__CT.nii.gz
# 580  image  CHUP-005__CT.nii.gz
# 582  image  MDA-003__CT.nii.gz
# 584  image  MDA-034__CT.nii.gz
# 585  image  MDA-117__CT.nii.gz
# 586  image  MDA-120__CT.nii.gz
# 587  image  MDA-061__CT.nii.gz
# 590  image  MDA-056__CT.nii.gz
# 592  image  MDA-175__CT.nii.gz
# 593  image  MDA-142__CT.nii.gz
# 599  image  CHUP-019__CT.nii.gz
# 603  image  CHUS-086__CT.nii.gz
# 605  image  CHUP-062__CT.nii.gz
# 607  image  CHUP-055__CT.nii.gz
# 609  image  MDA-193__CT.nii.gz
# 611  image  MDA-087__CT.nii.gz
# 613  image  CHUP-000__CT.nii.gz
# 615  image  CHUP-037__CT.nii.gz
# 619  image  CHUS-060__CT.nii.gz
# 620  image  CHUS-057__CT.nii.gz
# 621  image  MDA-139__CT.nii.gz
# 622  image  MDA-078__CT.nii.gz
# 623  image  CHUS-035__CT.nii.gz
# 625  image  CHUP-049__CT.nii.gz
# 629  image  CHUS-083__CT.nii.gz
# 632  image  MDA-125__CT.nii.gz
# 633  image  MDA-112__CT.nii.gz
# 635  image  MDA-031__CT.nii.gz
# 637  image  MDA-006__CT.nii.gz
# 638  image  MDA-147__CT.nii.gz
# 640  image  MDA-170__CT.nii.gz
# 642  image  MDA-053__CT.nii.gz
# 644  image  MDA-064__CT.nii.gz
# 647  image  MDA-075__CT.nii.gz
# 649  image  CHUS-038__CT.nii.gz
# 650  image  MDA-042__CT.nii.gz
# 651  image  MDA-161__CT.nii.gz
# 652  image  MDA-156__CT.nii.gz
# 654  image  MDA-017__CT.nii.gz
# 656  image  MDA-020__CT.nii.gz
# 658  image  MDA-103__CT.nii.gz
# 659  image  MDA-134__CT.nii.gz
# 663  image  CHUP-058__CT.nii.gz
# 665  image  CHUS-013__CT.nii.gz
# 666  image  MDA-069__CT.nii.gz
# 667  image  MDA-128__CT.nii.gz
# 668  image  CHUS-046__CT.nii.gz
# 672  image  CHUP-026__CT.nii.gz
# 674  image  CHUP-011__CT.nii.gz
# 675  image  MDA-096__CT.nii.gz
# 679  image  CHUP-044__CT.nii.gz
# 681  image  MDA-182__CT.nii.gz
# 682  image  CHUP-073__CT.nii.gz

# %%
ct_df_res
# Out:
#                File Name Institute          spacing             size modality
# 0     MDA-111__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 975)       CT
# 1     MDA-126__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 415)       CT
# 2     MDA-005__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 873)       CT
# 3    CHUS-048__CT.nii.gz      CHUS  (1.0, 1.0, 1.0)  (576, 576, 401)       CT
# 4     MDA-032__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (498, 498, 873)       CT
# ..                   ...       ...              ...              ...      ...
# 337  CHUP-011__CT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 849)       CT
# 338   MDA-096__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 415)       CT
# 339  CHUP-044__CT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 975)       CT
# 340   MDA-182__CT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 298)       CT
# 341  CHUP-073__CT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 849)       CT
#
# [342 rows x 5 columns]

# %%
ct_df_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   File Name  342 non-null    object
#  1   Institute  342 non-null    object
#  2   spacing    342 non-null    object
#  3   size       342 non-null    object
#  4   modality   342 non-null    object
# dtypes: object(5)
# memory usage: 13.5+ KB

# %%
pt_df_res = generate_summary(resampled_root_image_folder, 'PT')
pt_df_res.head()
# Out:
# 2  image  CHUP-002__PT.nii.gz
# 5  image  CHUP-035__PT.nii.gz
# 9  image  MDA-085__PT.nii.gz
# 11  image  CHUP-060__PT.nii.gz
# 12  image  MDA-191__PT.nii.gz
# 14  image  CHUP-057__PT.nii.gz
# 16  image  MDA-159__PT.nii.gz
# 18  image  MDA-018__PT.nii.gz
# 20  image  CHUS-055__PT.nii.gz
# 21  image  CHUP-029__PT.nii.gz
# 23  image  CHUS-081__PT.nii.gz
# 26  image  MDA-099__PT.nii.gz
# 27  image  MDA-051__PT.nii.gz
# 30  image  MDA-066__PT.nii.gz
# 33  image  MDA-145__PT.nii.gz
# 34  image  MDA-172__PT.nii.gz
# 35  image  CHUS-049__PT.nii.gz
# 37  image  MDA-033__PT.nii.gz
# 39  image  MDA-004__PT.nii.gz
# 40  image  MDA-127__PT.nii.gz
# 41  image  MDA-110__PT.nii.gz
# 42  image  MDA-101__PT.nii.gz
# 43  image  MDA-136__PT.nii.gz
# 44  image  MDA-015__PT.nii.gz
# 46  image  MDA-022__PT.nii.gz
# 48  image  CHUS-058__PT.nii.gz
# 49  image  MDA-163__PT.nii.gz
# 51  image  MDA-154__PT.nii.gz
# 53  image  MDA-077__PT.nii.gz
# 55  image  MDA-040__PT.nii.gz
# 58  image  MDA-088__PT.nii.gz
# 61  image  CHUS-090__PT.nii.gz
# 63  image  CHUP-038__PT.nii.gz
# 65  image  CHUS-073__PT.nii.gz
# 67  image  CHUS-026__PT.nii.gz
# 69  image  MDA-148__PT.nii.gz
# 70  image  MDA-180__PT.nii.gz
# 71  image  CHUP-046__PT.nii.gz
# 73  image  CHUP-071__PT.nii.gz
# 76  image  MDA-094__PT.nii.gz
# 79  image  CHUP-024__PT.nii.gz
# 81  image  CHUP-013__PT.nii.gz
# 84  image  MDA-199__PT.nii.gz
# 87  image  CHUP-068__PT.nii.gz
# 92  image  CHUS-095__PT.nii.gz
# 94  image  MDA-027__PT.nii.gz
# 96  image  MDA-010__PT.nii.gz
# 98  image  MDA-133__PT.nii.gz
# 100  image  MDA-104__PT.nii.gz
# 102  image  MDA-045__PT.nii.gz
# 104  image  CHUS-008__PT.nii.gz
# 106  image  MDA-072__PT.nii.gz
# 108  image  MDA-151__PT.nii.gz
# 109  image  MDA-166__PT.nii.gz
# 112  image  MDA-091__PT.nii.gz
# 114  image  CHUP-074__PT.nii.gz
# 116  image  MDA-185__PT.nii.gz
# 117  image  CHUP-043__PT.nii.gz
# 120  image  CHUS-089__PT.nii.gz
# 123  image  CHUP-016__PT.nii.gz
# 125  image  MDA-118__PT.nii.gz
# 127  image  CHUS-076__PT.nii.gz
# 128  image  CHUS-041__PT.nii.gz
# 129  image  CHUS-100__PT.nii.gz
# 131  image  MDA-059__PT.nii.gz
# 133  image  MDA-048__PT.nii.gz
# 135  image  CHUS-005__PT.nii.gz
# 136  image  CHUS-050__PT.nii.gz
# 137  image  CHUS-067__PT.nii.gz
# 139  image  MDA-109__PT.nii.gz
# 140  image  CHUP-030__PT.nii.gz
# 142  image  CHUP-007__PT.nii.gz
# 143  image  CHUS-098__PT.nii.gz
# 146  image  MDA-194__PT.nii.gz
# 148  image  CHUP-052__PT.nii.gz
# 150  image  CHUP-065__PT.nii.gz
# 152  image  MDA-080__PT.nii.gz
# 154  image  MDA-177__PT.nii.gz
# 156  image  MDA-140__PT.nii.gz
# 157  image  MDA-063__PT.nii.gz
# 159  image  CHUS-019__PT.nii.gz
# 160  image  MDA-054__PT.nii.gz
# 163  image  MDA-115__PT.nii.gz
# 164  image  MDA-122__PT.nii.gz
# 166  image  MDA-001__PT.nii.gz
# 167  image  MDA-036__PT.nii.gz
# 172  image  MDA-188__PT.nii.gz
# 178  image  CHUS-083__PT.nii.gz
# 181  image  CHUP-049__PT.nii.gz
# 182  image  MDA-064__PT.nii.gz
# 185  image  MDA-053__PT.nii.gz
# 187  image  MDA-170__PT.nii.gz
# 188  image  MDA-147__PT.nii.gz
# 191  image  MDA-006__PT.nii.gz
# 193  image  MDA-031__PT.nii.gz
# 194  image  MDA-112__PT.nii.gz
# 195  image  MDA-125__PT.nii.gz
# 198  image  CHUP-037__PT.nii.gz
# 200  image  CHUP-000__PT.nii.gz
# 202  image  MDA-087__PT.nii.gz
# 207  image  CHUP-055__PT.nii.gz
# 208  image  MDA-193__PT.nii.gz
# 210  image  CHUP-062__PT.nii.gz
# 212  image  CHUS-035__PT.nii.gz
# 213  image  MDA-078__PT.nii.gz
# 214  image  MDA-139__PT.nii.gz
# 215  image  CHUS-057__PT.nii.gz
# 216  image  CHUS-060__PT.nii.gz
# 217  image  CHUS-046__PT.nii.gz
# 218  image  MDA-128__PT.nii.gz
# 219  image  MDA-069__PT.nii.gz
# 220  image  CHUS-013__PT.nii.gz
# 222  image  CHUP-073__PT.nii.gz
# 224  image  CHUP-044__PT.nii.gz
# 227  image  MDA-182__PT.nii.gz
# 229  image  MDA-096__PT.nii.gz
# 232  image  CHUP-011__PT.nii.gz
# 234  image  CHUP-026__PT.nii.gz
# 237  image  MDA-134__PT.nii.gz
# 238  image  MDA-103__PT.nii.gz
# 239  image  MDA-020__PT.nii.gz
# 241  image  MDA-017__PT.nii.gz
# 243  image  MDA-156__PT.nii.gz
# 245  image  MDA-161__PT.nii.gz
# 247  image  MDA-042__PT.nii.gz
# 248  image  CHUS-038__PT.nii.gz
# 250  image  MDA-075__PT.nii.gz
# 251  image  CHUP-058__PT.nii.gz
# 255  image  MDA-093__PT.nii.gz
# 258  image  CHUP-041__PT.nii.gz
# 260  image  MDA-187__PT.nii.gz
# 265  image  CHUP-023__PT.nii.gz
# 269  image  CHUS-043__PT.nii.gz
# 270  image  MDA-039__PT.nii.gz
# 272  image  CHUS-074__PT.nii.gz
# 273  image  MDA-178__PT.nii.gz
# 274  image  CHUS-021__PT.nii.gz
# 275  image  CHUS-016__PT.nii.gz
# 278  image  CHUP-008__PT.nii.gz
# 281  image  CHUS-097__PT.nii.gz
# 282  image  CHUS-068__PT.nii.gz
# 283  image  MDA-012__PT.nii.gz
# 285  image  MDA-025__PT.nii.gz
# 287  image  MDA-106__PT.nii.gz
# 288  image  MDA-131__PT.nii.gz
# 289  image  MDA-070__PT.nii.gz
# 292  image  MDA-047__PT.nii.gz
# 293  image  MDA-164__PT.nii.gz
# 294  image  MDA-153__PT.nii.gz
# 296  image  MDA-142__PT.nii.gz
# 298  image  MDA-175__PT.nii.gz
# 300  image  MDA-056__PT.nii.gz
# 302  image  MDA-061__PT.nii.gz
# 304  image  MDA-120__PT.nii.gz
# 305  image  MDA-117__PT.nii.gz
# 307  image  MDA-034__PT.nii.gz
# 309  image  MDA-003__PT.nii.gz
# 310  image  CHUS-086__PT.nii.gz
# 314  image  CHUP-019__PT.nii.gz
# 319  image  CHUS-007__PT.nii.gz
# 320  image  MDA-200__PT.nii.gz
# 321  image  CHUS-030__PT.nii.gz
# 322  image  MDA-169__PT.nii.gz
# 323  image  CHUS-065__PT.nii.gz
# 325  image  MDA-028__PT.nii.gz
# 326  image  CHUS-052__PT.nii.gz
# 328  image  CHUP-005__PT.nii.gz
# 330  image  CHUP-032__PT.nii.gz
# 335  image  CHUP-067__PT.nii.gz
# 337  image  CHUP-050__PT.nii.gz
# 338  image  MDA-196__PT.nii.gz
# 340  image  MDA-082__PT.nii.gz
# 342  image  MDA-026__PT.nii.gz
# 343  image  MDA-011__PT.nii.gz
# 346  image  MDA-132__PT.nii.gz
# 347  image  MDA-105__PT.nii.gz
# 350  image  MDA-044__PT.nii.gz
# 352  image  MDA-073__PT.nii.gz
# 353  image  CHUS-009__PT.nii.gz
# 354  image  MDA-150__PT.nii.gz
# 356  image  MDA-167__PT.nii.gz
# 358  image  MDA-198__PT.nii.gz
# 359  image  CHUP-069__PT.nii.gz
# 363  image  CHUS-094__PT.nii.gz
# 365  image  MDA-119__PT.nii.gz
# 367  image  CHUS-077__PT.nii.gz
# 368  image  CHUS-040__PT.nii.gz
# 369  image  CHUS-101__PT.nii.gz
# 370  image  CHUS-015__PT.nii.gz
# 373  image  MDA-058__PT.nii.gz
# 374  image  CHUS-022__PT.nii.gz
# 376  image  MDA-090__PT.nii.gz
# 378  image  CHUP-075__PT.nii.gz
# 381  image  CHUP-042__PT.nii.gz
# 383  image  MDA-184__PT.nii.gz
# 386  image  CHUS-088__PT.nii.gz
# 388  image  CHUP-017__PT.nii.gz
# 390  image  CHUP-020__PT.nii.gz
# 392  image  CHUP-006__PT.nii.gz
# 397  image  CHUP-053__PT.nii.gz
# 398  image  MDA-195__PT.nii.gz
# 401  image  CHUP-064__PT.nii.gz
# 402  image  MDA-081__PT.nii.gz
# 406  image  CHUS-033__PT.nii.gz
# 407  image  MDA-049__PT.nii.gz
# 408  image  CHUS-004__PT.nii.gz
# 409  image  CHUS-051__PT.nii.gz
# 410  image  CHUS-066__PT.nii.gz
# 411  image  MDA-108__PT.nii.gz
# 413  image  CHUS-085__PT.nii.gz
# 418  image  MDA-189__PT.nii.gz
# 419  image  MDA-176__PT.nii.gz
# 420  image  MDA-141__PT.nii.gz
# 422  image  MDA-062__PT.nii.gz
# 425  image  MDA-055__PT.nii.gz
# 427  image  MDA-114__PT.nii.gz
# 429  image  MDA-123__PT.nii.gz
# 432  image  MDA-037__PT.nii.gz
# 433  image  MDA-158__PT.nii.gz
# 435  image  CHUS-036__PT.nii.gz
# 437  image  MDA-019__PT.nii.gz
# 441  image  CHUP-003__PT.nii.gz
# 443  image  CHUP-034__PT.nii.gz
# 447  image  MDA-084__PT.nii.gz
# 450  image  CHUP-061__PT.nii.gz
# 452  image  CHUP-056__PT.nii.gz
# 453  image  MDA-190__PT.nii.gz
# 455  image  MDA-050__PT.nii.gz
# 457  image  MDA-067__PT.nii.gz
# 459  image  MDA-144__PT.nii.gz
# 461  image  MDA-173__PT.nii.gz
# 463  image  MDA-032__PT.nii.gz
# 464  image  CHUS-048__PT.nii.gz
# 466  image  MDA-005__PT.nii.gz
# 467  image  MDA-126__PT.nii.gz
# 468  image  MDA-111__PT.nii.gz
# 470  image  CHUP-028__PT.nii.gz
# 472  image  CHUS-080__PT.nii.gz
# 473  image  MDA-098__PT.nii.gz
# 475  image  MDA-089__PT.nii.gz
# 478  image  CHUS-091__PT.nii.gz
# 480  image  CHUP-039__PT.nii.gz
# 481  image  MDA-100__PT.nii.gz
# 482  image  MDA-137__PT.nii.gz
# 483  image  MDA-014__PT.nii.gz
# 485  image  MDA-023__PT.nii.gz
# 487  image  MDA-162__PT.nii.gz
# 488  image  MDA-155__PT.nii.gz
# 491  image  MDA-076__PT.nii.gz
# 494  image  MDA-041__PT.nii.gz
# 495  image  CHUP-047__PT.nii.gz
# 497  image  MDA-181__PT.nii.gz
# 498  image  CHUP-070__PT.nii.gz
# 500  image  MDA-095__PT.nii.gz
# 505  image  CHUP-025__PT.nii.gz
# 507  image  CHUP-012__PT.nii.gz
# 511  image  CHUS-045__PT.nii.gz
# 513  image  CHUS-027__PT.nii.gz
# 514  image  CHUS-010__PT.nii.gz
# 515  image  MDA-149__PT.nii.gz
# 518  image  MDA-038__PT.nii.gz
# 519  image  CHUS-042__PT.nii.gz
# 521  image  MDA-179__PT.nii.gz
# 522  image  CHUS-020__PT.nii.gz
# 524  image  MDA-092__PT.nii.gz
# 526  image  MDA-186__PT.nii.gz
# 527  image  CHUP-040__PT.nii.gz
# 533  image  CHUP-022__PT.nii.gz
# 535  image  CHUP-015__PT.nii.gz
# 537  image  MDA-013__PT.nii.gz
# 538  image  CHUS-069__PT.nii.gz
# 539  image  MDA-024__PT.nii.gz
# 541  image  MDA-107__PT.nii.gz
# 542  image  MDA-130__PT.nii.gz
# 543  image  MDA-071__PT.nii.gz
# 545  image  MDA-046__PT.nii.gz
# 547  image  MDA-165__PT.nii.gz
# 549  image  MDA-152__PT.nii.gz
# 554  image  CHUP-009__PT.nii.gz
# 557  image  CHUS-096__PT.nii.gz
# 558  image  CHUS-087__PT.nii.gz
# 561  image  CHUP-018__PT.nii.gz
# 568  image  MDA-143__PT.nii.gz
# 569  image  MDA-174__PT.nii.gz
# 570  image  MDA-057__PT.nii.gz
# 573  image  MDA-060__PT.nii.gz
# 575  image  MDA-121__PT.nii.gz
# 576  image  MDA-116__PT.nii.gz
# 578  image  MDA-035__PT.nii.gz
# 579  image  CHUS-078__PT.nii.gz
# 581  image  CHUP-004__PT.nii.gz
# 583  image  CHUP-033__PT.nii.gz
# 588  image  CHUP-066__PT.nii.gz
# 589  image  MDA-197__PT.nii.gz
# 591  image  CHUP-051__PT.nii.gz
# 594  image  MDA-083__PT.nii.gz
# 595  image  MDA-201__PT.nii.gz
# 596  image  CHUS-006__PT.nii.gz
# 597  image  CHUS-031__PT.nii.gz
# 598  image  MDA-168__PT.nii.gz
# 600  image  CHUS-064__PT.nii.gz
# 601  image  CHUS-053__PT.nii.gz
# 602  image  MDA-029__PT.nii.gz
# 604  image  MDA-065__PT.nii.gz
# 606  image  MDA-052__PT.nii.gz
# 608  image  CHUS-028__PT.nii.gz
# 610  image  MDA-171__PT.nii.gz
# 612  image  MDA-146__PT.nii.gz
# 614  image  MDA-007__PT.nii.gz
# 616  image  MDA-030__PT.nii.gz
# 617  image  MDA-113__PT.nii.gz
# 618  image  MDA-124__PT.nii.gz
# 624  image  CHUP-048__PT.nii.gz
# 626  image  MDA-079__PT.nii.gz
# 627  image  CHUS-003__PT.nii.gz
# 628  image  MDA-138__PT.nii.gz
# 630  image  CHUS-056__PT.nii.gz
# 631  image  CHUS-061__PT.nii.gz
# 634  image  CHUP-036__PT.nii.gz
# 636  image  CHUP-001__PT.nii.gz
# 639  image  MDA-086__PT.nii.gz
# 641  image  MDA-192__PT.nii.gz
# 643  image  CHUP-054__PT.nii.gz
# 645  image  CHUP-063__PT.nii.gz
# 646  image  CHUP-072__PT.nii.gz
# 648  image  MDA-183__PT.nii.gz
# 653  image  MDA-097__PT.nii.gz
# 655  image  CHUP-010__PT.nii.gz
# 657  image  CHUP-027__PT.nii.gz
# 660  image  CHUS-047__PT.nii.gz
# 661  image  MDA-129__PT.nii.gz
# 662  image  MDA-068__PT.nii.gz
# 664  image  CHUP-059__PT.nii.gz
# 669  image  MDA-135__PT.nii.gz
# 670  image  MDA-102__PT.nii.gz
# 671  image  MDA-021__PT.nii.gz
# 673  image  MDA-016__PT.nii.gz
# 676  image  MDA-157__PT.nii.gz
# 677  image  MDA-160__PT.nii.gz
# 678  image  CHUS-039__PT.nii.gz
# 680  image  MDA-043__PT.nii.gz
# 683  image  MDA-074__PT.nii.gz
#              File Name Institute          spacing             size modality
# 0  CHUP-002__PT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 975)       PT
# 1  CHUP-035__PT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 975)       PT
# 2   MDA-085__PT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 415)       PT
# 3  CHUP-060__PT.nii.gz      CHUP  (1.0, 1.0, 1.0)  (500, 500, 849)       PT
# 4   MDA-191__PT.nii.gz      MDA-  (1.0, 1.0, 1.0)  (500, 500, 415)       PT

# %% [markdown]
# **concatenate both data frames**

# %%
images_df_res = pd.concat([ct_df_res, pt_df_res])

# %%
images_df_res.groupby(by=['Institute', 'modality']).count()
# Out:
#                     File Name  spacing  size
# Institute modality
# CHUP      CT               72       72    72
#           PT               72       72    72
# CHUS      CT               72       72    72
#           PT               72       72    72
# MDA-      CT              198      198   198
#           PT              198      198   198

# %% [markdown]
# **Add Some Columns**

# %%
# add spacing x,y,z coordinates
images_df_res['spacing_x'] = images_df_res['spacing'].apply(lambda x: x[1:-1].split(',')[0]).astype(float)
images_df_res['spacing_y'] = images_df_res['spacing'].apply(lambda x: x[1:-1].split(',')[1]).astype(float)
images_df_res['spacing_z'] = images_df_res['spacing'].apply(lambda x: x[1:-1].split(',')[2]).astype(float)

# %%
# add spacing x,y,z coordinates
images_df_res['size_x'] = images_df_res['size'].apply(lambda x: x[1:-1].split(',')[0]).astype(float)
images_df_res['size_y'] = images_df_res['size'].apply(lambda x: x[1:-1].split(',')[1]).astype(float)
images_df_res['size_z'] = images_df_res['size'].apply(lambda x: x[1:-1].split(',')[2]).astype(float)

# %%
# fix institute
def fix_institute(institute):
    if institute.endswith('-'):
        return institute.split('-')[0]
    return institute

# %%
images_df_res['Institute'] = images_df_res['Institute'].apply(lambda x: fix_institute(x))

# %%
images_df_res.tail()
# Out:
#                File Name Institute          spacing              size  \
# 337   MDA-157__PT.nii.gz       MDA  (1.0, 1.0, 1.0)  (697, 697, 1095)
# 338   MDA-160__PT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 415)
# 339  CHUS-039__PT.nii.gz      CHUS  (1.0, 1.0, 1.0)   (576, 576, 402)
# 340   MDA-043__PT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 415)
# 341   MDA-074__PT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 1101)
#
#     modality  spacing_x  spacing_y  spacing_z  size_x  size_y  size_z
# 337       PT        1.0        1.0        1.0   697.0   697.0  1095.0
# 338       PT        1.0        1.0        1.0   500.0   500.0   415.0
# 339       PT        1.0        1.0        1.0   576.0   576.0   402.0
# 340       PT        1.0        1.0        1.0   500.0   500.0   415.0
# 341       PT        1.0        1.0        1.0   500.0   500.0  1101.0

# %% [markdown]
# ### Get images summaries

# %%
spacing_info_res = images_df_res.groupby(by=['Institute', 'modality'])[['spacing_x', 'spacing_y', 'spacing_z']].mean()

# %%
image_count_info_res = images_df_res.groupby(by=['Institute', 'modality'])[['File Name']].count()

# %%
spacing_info_res
# Out:
#                     spacing_x  spacing_y  spacing_z
# Institute modality
# CHUP      CT              1.0        1.0        1.0
#           PT              1.0        1.0        1.0
# CHUS      CT              1.0        1.0        1.0
#           PT              1.0        1.0        1.0
# MDA       CT              1.0        1.0        1.0
#           PT              1.0        1.0        1.0

# %%
# image_size_info_res
images_df_res.groupby(by=['Institute', 'modality'])[['size_x', 'size_y', 'size_z']].value_counts()
# Out:
# Institute  modality  size_x  size_y  size_z
# CHUP       CT        500.0   500.0   975.0     35
#                                      849.0     30
#                                      1101.0     6
#                                      724.0      1
#            PT        500.0   500.0   975.0     35
#                                                ..
# MDA        PT        250.0   250.0   295.0      1
#                      500.0   500.0   988.0      1
#                      498.0   498.0   873.0      1
#                                      1017.0     1
#                      780.0   780.0   348.0      1
# Name: count, Length: 170, dtype: int64

# %%
images_df_res[(images_df_res['Institute']=='CHUP')&(images_df_res['modality']=='CT')]['size_x'].value_counts()
# Out:
# size_x
# 500.0    72
# Name: count, dtype: int64

# %%
information_res = pd.concat([spacing_info_res, image_count_info_res], axis=1)
information_res
# Out:
#                     spacing_x  spacing_y  spacing_z  File Name
# Institute modality
# CHUP      CT              1.0        1.0        1.0         72
#           PT              1.0        1.0        1.0         72
# CHUS      CT              1.0        1.0        1.0         72
#           PT              1.0        1.0        1.0         72
# MDA       CT              1.0        1.0        1.0        198
#           PT              1.0        1.0        1.0        198

# %% [markdown]
# images have been resampled to 1x1x1 but some of the images are not correctly resampled, so we need to exclude them
#
# - Institute CHUS remove all images and just keep CHUP as the target dataset
# - MDA we have 183 images that were done correctly we just need to keep them and exclude the rest

# %% [markdown]
# ## save resampled images dataframe

# %%
# choose where to save the images 
resampled_root_folder
# Out:
# '../../datasets/ADDA/resampled/'

# %%
images_df_res.to_csv(os.path.join(resampled_root_folder,'images_info.csv'), index=False)

# %% [markdown]
# ### Remove mismatched images

# %%
ineligible_mda = images_df_res[(images_df_res['Institute']=='MDA')&(images_df_res['size_x']!=500)]

# %% [markdown]
# ## Select Source and Target Datasets

# %%
source_res = images_df_res[images_df_res['Institute']=='MDA']

# %%
source_res
# Out:
#               File Name Institute          spacing              size modality  \
# 0    MDA-111__CT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 975)       CT
# 1    MDA-126__CT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 415)       CT
# 2    MDA-005__CT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 873)       CT
# 4    MDA-032__CT.nii.gz       MDA  (1.0, 1.0, 1.0)   (498, 498, 873)       CT
# 5    MDA-173__CT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 298)       CT
# ..                  ...       ...              ...               ...      ...
# 336  MDA-016__PT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 441)       PT
# 337  MDA-157__PT.nii.gz       MDA  (1.0, 1.0, 1.0)  (697, 697, 1095)       PT
# 338  MDA-160__PT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 415)       PT
# 340  MDA-043__PT.nii.gz       MDA  (1.0, 1.0, 1.0)   (500, 500, 415)       PT
# 341  MDA-074__PT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 1101)       PT
#
#      spacing_x  spacing_y  spacing_z  size_x  size_y  size_z
# 0          1.0        1.0        1.0   500.0   500.0   975.0
# 1          1.0        1.0        1.0   500.0   500.0   415.0
# 2          1.0        1.0        1.0   500.0   500.0   873.0
# 4          1.0        1.0        1.0   498.0   498.0   873.0
# 5          1.0        1.0        1.0   500.0   500.0   298.0
# ..         ...        ...        ...     ...     ...     ...
# 336        1.0        1.0        1.0   500.0   500.0   441.0
# 337        1.0        1.0        1.0   697.0   697.0  1095.0
# 338        1.0        1.0        1.0   500.0   500.0   415.0
# 340        1.0        1.0        1.0   500.0   500.0   415.0
# 341        1.0        1.0        1.0   500.0   500.0  1101.0
#
# [396 rows x 11 columns]

# %%
target_res =  images_df_res[images_df_res['Institute']=='CHUP']

# %%
source_res.head()
# Out:
#             File Name Institute          spacing             size modality  \
# 0  MDA-111__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 975)       CT
# 1  MDA-126__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 415)       CT
# 2  MDA-005__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 873)       CT
# 4  MDA-032__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (498, 498, 873)       CT
# 5  MDA-173__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 298)       CT
#
#    spacing_x  spacing_y  spacing_z  size_x  size_y  size_z
# 0        1.0        1.0        1.0   500.0   500.0   975.0
# 1        1.0        1.0        1.0   500.0   500.0   415.0
# 2        1.0        1.0        1.0   500.0   500.0   873.0
# 4        1.0        1.0        1.0   498.0   498.0   873.0
# 5        1.0        1.0        1.0   500.0   500.0   298.0

# %%
source_res['label_name'] = source_res['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
# Out:
# /var/folders/wg/_bw301w169bd2mdb38l8r5j80000gn/T/ipykernel_64418/411886394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   source_res['label_name'] = source_res['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))

# %%
source_res.head()
# Out:
#             File Name Institute          spacing             size modality  \
# 0  MDA-111__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 975)       CT
# 1  MDA-126__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 415)       CT
# 2  MDA-005__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 873)       CT
# 4  MDA-032__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (498, 498, 873)       CT
# 5  MDA-173__CT.nii.gz       MDA  (1.0, 1.0, 1.0)  (500, 500, 298)       CT
#
#    spacing_x  spacing_y  spacing_z  size_x  size_y  size_z      label_name
# 0        1.0        1.0        1.0   500.0   500.0   975.0  MDA-111.nii.gz
# 1        1.0        1.0        1.0   500.0   500.0   415.0  MDA-126.nii.gz
# 2        1.0        1.0        1.0   500.0   500.0   873.0  MDA-005.nii.gz
# 4        1.0        1.0        1.0   498.0   498.0   873.0  MDA-032.nii.gz
# 5        1.0        1.0        1.0   500.0   500.0   298.0  MDA-173.nii.gz

# %%
source_res['label_name'].nunique()
# Out:
# 198

# %%
source_res['File Name'].nunique()
# Out:
# 396

# %%
target_res['label_name'] = target_res['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))
# Out:
# /var/folders/wg/_bw301w169bd2mdb38l8r5j80000gn/T/ipykernel_64418/14702590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_res['label_name'] = target_res['File Name'].apply(lambda x: x.replace('__CT', '').replace('__PT', ''))

# %% [markdown]
# ### create CSV list of source and targets

# %%
source_res[['File Name', 'label_name', 'modality']].to_csv(os.path.join(resampled_root_folder, 'source_images.csv'),
                           header=True, index=False)

# %%
target_res[['File Name', 'label_name', 'modality']].to_csv(os.path.join(resampled_root_folder, 'target_images.csv'),
                           header=True, index=False)

# %%
source_res_list = pd.read_csv(os.path.join(resampled_root_folder, 'source_images.csv'))
source_res_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   396 non-null    object
#  1   label_name  396 non-null    object
#  2   modality    396 non-null    object
# dtypes: object(3)
# memory usage: 9.4+ KB

# %%
target_res_list = pd.read_csv(os.path.join(resampled_root_folder, 'target_images.csv'))
target_res_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   144 non-null    object
#  1   label_name  144 non-null    object
#  2   modality    144 non-null    object
# dtypes: object(3)
# memory usage: 3.5+ KB

# %%
target_res_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   File Name   144 non-null    object
#  1   label_name  144 non-null    object
#  2   modality    144 non-null    object
# dtypes: object(3)
# memory usage: 3.5+ KB

# %%
target_res = pd.read_csv('../../datasets/ADDA/original/')

# %% [markdown]
# # Sandbox

# %%
images_df_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 684 entries, 0 to 341
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   File Name  684 non-null    object
#  1   Institute  684 non-null    object
#  2   spacing    684 non-null    object
#  3   size       684 non-null    object
#  4   modality   684 non-null    object
#  5   spacing_x  684 non-null    float64
#  6   spacing_y  684 non-null    float64
#  7   spacing_z  684 non-null    float64
#  8   size_x     684 non-null    float64
#  9   size_y     684 non-null    float64
#  10  size_z     684 non-null    float64
# dtypes: float64(6), object(5)
# memory usage: 64.1+ KB

# %%
images_df_res['Institute'].unique()
# Out:
# array(['MDA', 'CHUS', 'CHUP'], dtype=object)

# %%
images_df_res[images_df_res['Institute']=='MDA']['size'].value_counts()
# Out:
# size
# (500, 500, 415)     208
# (500, 500, 1017)     34
# (500, 500, 298)      24
# (500, 500, 389)      20
# (500, 500, 873)      12
# (500, 500, 284)      12
# (500, 500, 441)       6
# (500, 500, 1095)      4
# (500, 500, 938)       4
# (500, 500, 375)       4
# (500, 500, 729)       4
# (498, 498, 441)       4
# (500, 500, 975)       4
# (500, 500, 965)       4
# (500, 500, 1069)      4
# (500, 500, 348)       4
# (500, 500, 978)       4
# (498, 498, 1017)      2
# (697, 697, 938)       2
# (500, 500, 414)       2
# (500, 500, 808)       2
# (500, 500, 1331)      2
# (780, 780, 348)       2
# (500, 500, 858)       2
# (250, 250, 295)       2
# (500, 500, 988)       2
# (697, 697, 1095)      2
# (500, 500, 1101)      2
# (698, 698, 1095)      2
# (615, 615, 1095)      2
# (500, 500, 1040)      2
# (250, 250, 412)       2
# (250, 250, 372)       2
# (698, 698, 389)       2
# (500, 500, 1161)      2
# (498, 498, 873)       2
# (350, 350, 273)       2
# Name: count, dtype: int64
